# %% [markdown]
# <a href="https://colab.research.google.com/github/oumaimaoubaha/sna_game_recommendation/blob/main/SNA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gzip
import json
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import community.community_louvain as community_louvain
import pickle

# %%
file_path = "/content/Video_Games_5.json.gz"

data = []

print("📥 Lecture du fichier...")

with gzip.open(file_path, 'rt', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line))

print("✅ Fichier lu ! Nombre de lignes :", len(data))

df = pd.DataFrame(data)

# Aperçu
df.head()
# Out:
# 📥 Lecture du fichier...
# ✅ Fichier lu ! Nombre de lignes : 497577
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True  10 17, 2015  A1HP7NVNPFMA4N  0700026657
# 1      4.0     False  07 27, 2015  A1JGAP0185YJI6  0700026657
# 2      3.0      True  02 23, 2015  A1YJWEXHQBWK2B  0700026657
# 3      2.0      True  02 20, 2015  A2204E1TH211HT  0700026657
# 4      5.0      True  12 25, 2014  A2RF5B5H74JLPE  0700026657
#
#         reviewerName                                         reviewText  \
# 0        Ambrosia075  This game is a bit hard to get the hang of, bu...
# 1             travis  I played it a while but it was alright. The st...
# 2  Vincent G. Mezera                                           ok game.
# 3         Grandma KR  found the game a bit too complicated, not what...
# 4                jon  great game, I love it and have played it since...
#
#                                        summary  unixReviewTime vote style  \
# 0                  but when you do it's great.      1445040000  NaN   NaN
# 1  But in spite of that it was fun, I liked it      1437955200  NaN   NaN
# 2                                  Three Stars      1424649600  NaN   NaN
# 3                                    Two Stars      1424390400  NaN   NaN
# 4                               love this game      1419465600  NaN   NaN
#
#   image
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %% [markdown]
# **Choix des colonnes utiles**

# %%
df = df[['reviewerID', 'asin', 'overall', 'unixReviewTime']]
df.head()
# Out:
#        reviewerID        asin  overall  unixReviewTime
# 0  A1HP7NVNPFMA4N  0700026657      5.0      1445040000
# 1  A1JGAP0185YJI6  0700026657      4.0      1437955200
# 2  A1YJWEXHQBWK2B  0700026657      3.0      1424649600
# 3  A2204E1TH211HT  0700026657      2.0      1424390400
# 4  A2RF5B5H74JLPE  0700026657      5.0      1419465600

# %% [markdown]
# **Les vrais dates**

# %%
import pandas as pd

# 1) Convertir le timestamp en vraie date
df['date'] = pd.to_datetime(df['unixReviewTime'], unit='s')

# 2) Extraire l'année
df['year'] = df['date'].dt.year

# 3) Extraire le mois (numéro 1..12)
df['month'] = df['date'].dt.month

# 4) Vérifier le résultat
df[['unixReviewTime', 'date', 'year', 'month']].head()
# Out:
#    unixReviewTime       date  year  month
# 0      1445040000 2015-10-17  2015     10
# 1      1437955200 2015-07-27  2015      7
# 2      1424649600 2015-02-23  2015      2
# 3      1424390400 2015-02-20  2015      2
# 4      1419465600 2014-12-25  2014     12

# %% [markdown]
# # Gérer les doublans

# %%
df.duplicated().sum()
# Out:
# np.int64(23718)

# %% [markdown]
# **Analyse**

# %%
df[df.duplicated()].head(10)
# Out:
#            reviewerID        asin  overall  unixReviewTime       date  year  \
# 969    A1CDNTB7377YH2  B00000DMAQ      5.0      1178150400 2007-05-03  2007
# 2409    AROWZGGO4VTJU  B00000INR2      1.0      1325635200 2012-01-04  2012
# 4804   A3L14D8BAREUSV  B00001NFS5      5.0      1162857600 2006-11-07  2006
# 6848   A2R164STV36F6C  B00002DHEV      4.0      1393804800 2014-03-03  2014
# 8316   A36UKFV79879MD  B00002STX3      4.0      1316044800 2011-09-15  2011
# 11365   AER15RIMV8E6D  B000035Y3N      5.0      1317513600 2011-10-02  2011
# 12849   A74TA8X5YQ7NE  B00004KHB7      5.0      1206316800 2008-03-24  2008
# 13113   A8TCAEBMUQ3VP  B00004R9I4      5.0       969840000 2000-09-25  2000
# 13172   A8TCAEBMUQ3VP  B00004R9I4      5.0       969840000 2000-09-25  2000
# 13173   A8TCAEBMUQ3VP  B00004R9I4      5.0       969840000 2000-09-25  2000
#
#        month
# 969        5
# 2409       1
# 4804      11
# 6848       3
# 8316       9
# 11365     10
# 12849      3
# 13113      9
# 13172      9
# 13173      9

# %%
df[df.duplicated(keep=False)].sort_values(by=['reviewerID', 'asin']).head(20)
# Out:
#                   reviewerID        asin  overall  unixReviewTime       date  \
# 119730  A0059486XI1Z0P98KP35  B000WE8JES      5.0      1402099200 2014-06-07
# 142958  A0059486XI1Z0P98KP35  B000WE8JES      5.0      1402099200 2014-06-07
# 122102  A0220159ZRNBTRKLG08H  B000X37732      5.0      1428710400 2015-04-11
# 145330  A0220159ZRNBTRKLG08H  B000X37732      5.0      1428710400 2015-04-11
# 140450  A0685888WB02Q69S553P  B0017XFP8G      3.0      1416268800 2014-11-18
# 163678  A0685888WB02Q69S553P  B0017XFP8G      3.0      1416268800 2014-11-18
# 136443   A0695568PX4DBZOQDN8  B0016B28WU      5.0      1361318400 2013-02-20
# 159671   A0695568PX4DBZOQDN8  B0016B28WU      5.0      1361318400 2013-02-20
# 139943  A0815906MFVDTIFHGRQR  B0017KIBAI      5.0      1384819200 2013-11-19
# 163171  A0815906MFVDTIFHGRQR  B0017KIBAI      5.0      1384819200 2013-11-19
# 132095  A0950144Z8AAFXJIXH4L  B0013OM528      5.0      1353801600 2012-11-25
# 155323  A0950144Z8AAFXJIXH4L  B0013OM528      5.0      1353801600 2012-11-25
# 134961        A100IX1FUK5IAW  B0015HYPOO      5.0      1421884800 2015-01-22
# 158189        A100IX1FUK5IAW  B0015HYPOO      5.0      1421884800 2015-01-22
# 119866        A100JCBNALJFAW  B000WEQL02      3.0      1205971200 2008-03-20
# 143094        A100JCBNALJFAW  B000WEQL02      3.0      1205971200 2008-03-20
# 120802        A100JCBNALJFAW  B000WSB04U      3.0      1202774400 2008-02-12
# 144030        A100JCBNALJFAW  B000WSB04U      3.0      1202774400 2008-02-12
# 124297        A100JCBNALJFAW  B000ZJVDA2      4.0      1205193600 2008-03-11
# 147525        A100JCBNALJFAW  B000ZJVDA2      4.0      1205193600 2008-03-11
#
#         year  month
# 119730  2014      6
# 142958  2014      6
# 122102  2015      4
# 145330  2015      4
# 140450  2014     11
# 163678  2014     11
# 136443  2013      2
# 159671  2013      2
# 139943  2013     11
# 163171  2013     11
# 132095  2012     11
# 155323  2012     11
# 134961  2015      1
# 158189  2015      1
# 119866  2008      3
# 143094  2008      3
# 120802  2008      2
# 144030  2008      2
# 124297  2008      3
# 147525  2008      3

# %% [markdown]
# **Supprimer**

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (473859, 7)

# %% [markdown]
# # Gerer les valeur manquants
#
# > Ajouter une citation

# %%
df.isna().sum()
# Out:
# reviewerID        0
# asin              0
# overall           0
# unixReviewTime    0
# date              0
# year              0
# month             0
# dtype: int64

# %%
df[df['reviewerID'].isna()]
df[df['asin'].isna()]
# Out:
# Empty DataFrame
# Columns: [reviewerID, asin, overall, unixReviewTime, date, year, month]
# Index: []

# %% [markdown]
# # Analyse

# %% [markdown]
# Analyse nombre d'avis par année

# %%
year_counts = df['year'].value_counts().sort_index()
print(year_counts)
# Out:
# year
# 1999       81
# 2000     1855
# 2001     5117
# 2002     7344
# 2003     6983
# 2004     7235
# 2005     7763
# 2006     7031
# 2007    10284
# 2008    14973
# 2009    16573
# 2010    16036
# 2011    17623
# 2012    24457
# 2013    45601
# 2014    70980
# 2015    88822
# 2016    74659
# 2017    38785
# 2018    11657
# Name: count, dtype: int64

# %% [markdown]
# statistiques globales

# %%
print("Nombre total de lignes :", len(df))
print("Nombre d'utilisateurs uniques :", df['reviewerID'].nunique())
print("Nombre de jeux uniques :", df['asin'].nunique())
# Out:
# Nombre total de lignes : 473859
# Nombre d'utilisateurs uniques : 55223
# Nombre de jeux uniques : 17408

# %%
user_counts = df['reviewerID'].value_counts()
print(user_counts.describe())
# Out:
# count    55223.000000
# mean         8.580827
# std         10.132530
# min          1.000000
# 25%          5.000000
# 50%          6.000000
# 75%          9.000000
# max        780.000000
# Name: count, dtype: float64

# %% [markdown]
# La distribution du nombre d’avis par utilisateur est très asymétrique : la majorité des utilisateurs sont peu actifs, tandis qu’une minorité très active contribue à une part importante des interactions.

# %%
game_counts = df['asin'].value_counts()
print(game_counts.describe())
# Out:
# count    17408.000000
# mean        27.220761
# std         47.462580
# min          1.000000
# 25%          7.000000
# 50%         12.000000
# 75%         27.000000
# max        783.000000
# Name: count, dtype: float64

# %% [markdown]
# La distribution du nombre d’avis par jeu présente une longue traîne : beaucoup de jeux sont peu populaires, tandis que quelques titres concentrent une énorme activité

# %%
print("\nRésumé des notes :")
print(df['overall'].describe())
# Out:
# Résumé des notes :
# count    473859.000000
# mean          4.226289
# std           1.182610
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: overall, dtype: float64

# %% [markdown]
# La distribution des notes est fortement biaisée vers les valeurs élevées, ce qui reflète un biais de positivité classique dans les systèmes d’avis en ligne

# %% [markdown]
# Décision

# %%
user_counts = df['reviewerID'].value_counts()
active_users = user_counts[user_counts >= 5].index

df = df[df['reviewerID'].isin(active_users)]
print("Après filtrage users :", df.shape)
# Out:
# Après filtrage users : (457558, 7)

# %%
game_counts = df['asin'].value_counts()
active_games = game_counts[game_counts >= 5].index

df = df[df['asin'].isin(active_games)]
print("Après filtrage jeux :", df.shape)
# Out:
# Après filtrage jeux : (456080, 7)

# %%
print("Final - nombre de lignes :", df.shape[0])
print("Final - utilisateurs uniques :", df['reviewerID'].nunique())
print("Final - jeux uniques :", df['asin'].nunique())
# Out:
# Final - nombre de lignes : 456080
# Final - utilisateurs uniques : 50997
# Final - jeux uniques : 16958

# %%
df.to_csv("dataset_clean.csv", index=False)
print("✔️ Dataset sauvegardé en dataset_clean.csv")
# Out:
# ✔️ Dataset sauvegardé en dataset_clean.csv

# %%
df = pd.read_csv("dataset_clean.csv")
print(df.shape)
df.head()
# Out:
# (456080, 7)
#        reviewerID        asin  overall  unixReviewTime        date  year  \
# 0  A1HP7NVNPFMA4N  0700026657      5.0      1445040000  2015-10-17  2015
# 1  A1JGAP0185YJI6  0700026657      4.0      1437955200  2015-07-27  2015
# 2  A1YJWEXHQBWK2B  0700026657      3.0      1424649600  2015-02-23  2015
# 3  A2RF5B5H74JLPE  0700026657      5.0      1419465600  2014-12-25  2014
# 4  A11V6ZJ2FVQY1D  0700026657      4.0      1415836800  2014-11-13  2014
#
#    month
# 0     10
# 1      7
# 2      2
# 3     12
# 4     11

# %% [markdown]
# #**Construction du graphe bipartie**

# %% [markdown]
# **Créer un graphe bipartite vide**

# %%
B = nx.Graph()

# %% [markdown]
# **Ajouter les nœuds utilisateurs**

# %%
users = df['reviewerID'].unique()
B.add_nodes_from(users, bipartite='user')

# %% [markdown]
# **Ajouter les nœuds Jeux**

# %%
games = df['asin'].unique()
B.add_nodes_from(games, bipartite='game')

# %% [markdown]
# **Ajout des arêtes User → Game**

# %%
edges = list(zip(df['reviewerID'], df['asin'], df['overall']))
B.add_weighted_edges_from(edges)

# %% [markdown]
# Chaque ligne de notre dataset est représent comme cette façon=
# Un utilisateur → un jeu (avec une note)
# nœud A = reviewerID,
# nœud B = asin (jeu),
# poids = note (overall)

# %% [markdown]
# **nombre des noeuds**

# %%
B.number_of_nodes()
# Out:
# 67955

# %% [markdown]
# **nombre des arêtes**

# %%
B.number_of_edges()
# Out:
# 455656

# %% [markdown]
# Nous avons construit un graphe bipartite où chaque utilisateur et chaque jeu sont représentés comme des nœuds appartenant à deux partitions distinctes. Chaque avis constitue une arête reliant un utilisateur à un jeu, pondérée par la note attribuée. Ce graphe constitue la base de notre analyse de réseau et de notre système de recommandation

# %% [markdown]
# ##Analyse structurale du réseau

# %% [markdown]
# **Séparer les deux types de nœuds (user / game)**

# %%
users_nodes = {n for n, d in B.nodes(data=True) if d['bipartite'] == 'user'}
games_nodes = set(B) - users_nodes

print("Users :", len(users_nodes))
print("Games :", len(games_nodes))
# Out:
# Users : 50997
# Games : 16958

# %% [markdown]
# puisque notre graphe est un graphe bipartie donc on est obligé de séparer les noeuds Certaines métriques doivent être calculées séparément pour utilisateurs et jeux

# %% [markdown]
# **Calculer les degrés des nœuds**

# %%
degree_dict = dict(B.degree())

user_degrees = [degree_dict[n] for n in users_nodes]
game_degrees = [degree_dict[n] for n in games_nodes]

# %%
print("Degree utilisateur (moyen) :", np.mean(user_degrees))
print("Degree jeu (moyen) :", np.mean(game_degrees))
# Out:
# Degree utilisateur (moyen) : 8.934956958252446
# Degree jeu (moyen) : 26.869678028069348

# %% [markdown]
# Le degré des nœuds côté utilisateurs correspond au nombre de jeux notés, tandis que le degré côté jeux correspond au nombre d’utilisateurs ayant interagi avec chaque titre. Ces distributions sont au cœur de notre analyse de popularité et d’activité

# %% [markdown]
# **Visualiser les distributions des degrés**

# %%
plt.hist(user_degrees, bins=50)
plt.title("Distribution du degré des utilisateurs")

plt.hist(game_degrees, bins=50)
plt.title("Distribution du degré des jeux")
# Out:
# Text(0.5, 1.0, 'Distribution du degré des jeux')

# %% [markdown]
# La distribution du degré des jeux montre que la majorité des titres ne reçoivent que très peu d’avis, tandis qu’une minorité très restreinte concentre un nombre élevé d’interactions. Ce comportement en longue traîne est typique des plateformes d’e-commerce comme Amazon

# %% [markdown]
# **Densité du graphe**

# %%
print("Densité du graphe :", nx.density(B))
# Out:
# Densité du graphe : 0.00019734705342954617

# %% [markdown]
# La densité du graphe est extrêmement faible (≈0.02%), ce qui est typique des réseaux utilisateur–produit. En effet, chaque utilisateur n’interagit qu’avec une petite fraction des jeux disponibles, et chaque jeu n’est noté que par une minorité d’utilisateurs. Cette structure sparse est caractéristique des systèmes de recommandation à grande échelle

# %% [markdown]
# ##Analyse dynamique du réseau (par année)

# %% [markdown]
# **Découper les données par année**

# %%
years = sorted(df['year'].unique())
years
# Out:
# [np.int64(1999),
#  np.int64(2000),
#  np.int64(2001),
#  np.int64(2002),
#  np.int64(2003),
#  np.int64(2004),
#  np.int64(2005),
#  np.int64(2006),
#  np.int64(2007),
#  np.int64(2008),
#  np.int64(2009),
#  np.int64(2010),
#  np.int64(2011),
#  np.int64(2012),
#  np.int64(2013),
#  np.int64(2014),
#  np.int64(2015),
#  np.int64(2016),
#  np.int64(2017),
#  np.int64(2018)]

# %% [markdown]
# **Construire un graphe bipartite par année**

# %%
graphs_by_year = {}

for y in years:
    df_year = df[df['year'] == y]
    B_y = nx.Graph()

    users_y = df_year['reviewerID'].unique()
    B_y.add_nodes_from(users_y, bipartite='user')

    games_y = df_year['asin'].unique()
    B_y.add_nodes_from(games_y, bipartite='game')

    edges_y = list(zip(df_year['reviewerID'], df_year['asin'], df_year['overall']))
    B_y.add_weighted_edges_from(edges_y)

    graphs_by_year[y] = B_y

# %% [markdown]
# Pour chaque année :
#
# 1-On filtre seulement les avis de cette année,
#
# 2-On crée un graphe vide,
#
# 3-On ajoute les utilisateurs de cette année,
#
# 4-On ajoute les jeux notés cette année,
#
# 5-On crée les liens user → game de cette année

# %% [markdown]
# **Calculer les stats annuelles**

# %%
stats = []

for y in years:
    G = graphs_by_year[y]
    stats.append({
        'year': y,
        'nodes': G.number_of_nodes(),
        'edges': G.number_of_edges(),
        'density': nx.density(G)
    })

stats
# Out:
# [{'year': np.int64(1999),
#   'nodes': 101,
#   'edges': 81,
#   'density': 0.01603960396039604},
#  {'year': np.int64(2000),
#   'nodes': 1108,
#   'edges': 1841,
#   'density': 0.003001901258483102},
#  {'year': np.int64(2001),
#   'nodes': 2461,
#   'edges': 5084,
#   'density': 0.0016795340647433293},
#  {'year': np.int64(2002),
#   'nodes': 3194,
#   'edges': 7286,
#   'density': 0.0014288457001569456},
#  {'year': np.int64(2003),
#   'nodes': 3475,
#   'edges': 6916,
#   'density': 0.0011457776783754343},
#  {'year': np.int64(2004),
#   'nodes': 3825,
#   'edges': 7165,
#   'density': 0.0009797084803237891},
#  {'year': np.int64(2005),
#   'nodes': 4250,
#   'edges': 7670,
#   'density': 0.0008494732324560797},
#  {'year': np.int64(2006),
#   'nodes': 4432,
#   'edges': 6884,
#   'density': 0.000701082869543184},
#  {'year': np.int64(2007),
#   'nodes': 6078,
#   'edges': 9839,
#   'density': 0.0005327592810115961},
#  {'year': np.int64(2008),
#   'nodes': 7754,
#   'edges': 13167,
#   'density': 0.0004380475448760863},
#  {'year': np.int64(2009),
#   'nodes': 9259,
#   'edges': 14788,
#   'density': 0.00034503104777795736},
#  {'year': np.int64(2010),
#   'nodes': 9707,
#   'edges': 14651,
#   'density': 0.00031100827711667497},
#  {'year': np.int64(2011),
#   'nodes': 11456,
#   'edges': 16410,
#   'density': 0.0002500981494261002},
#  {'year': np.int64(2012),
#   'nodes': 14602,
#   'edges': 23035,
#   'density': 0.0002160843266763132},
#  {'year': np.int64(2013),
#   'nodes': 22575,
#   'edges': 43406,
#   'density': 0.00017035052723362592},
#  {'year': np.int64(2014),
#   'nodes': 29851,
#   'edges': 68612,
#   'density': 0.0001540021750686141},
#  {'year': np.int64(2015),
#   'nodes': 34298,
#   'edges': 86337,
#   'density': 0.00014679187577110175},
#  {'year': np.int64(2016),
#   'nodes': 31255,
#   'edges': 73074,
#   'density': 0.0001496124605472992},
#  {'year': np.int64(2017),
#   'nodes': 21214,
#   'edges': 38108,
#   'density': 0.00016936415346715795},
#  {'year': np.int64(2018),
#   'nodes': 9551,
#   'edges': 11464,
#   'density': 0.0002513702959203307}]

# %% [markdown]
# Le réseau se développe fortement jusqu’en 2015, puis il se réduit. En même temps, la densité devient de plus en plus faible, ce qui est normal dans les réseaux utilisateur–produit

# %% [markdown]
# **Nombre d’arêtes par année**

# %%
df_stats = pd.DataFrame(stats)

df_stats.plot(x='year', y='edges', kind='line', title='Évolution du nombre d’interactions par année')
# Out:
# <Axes: title={'center': 'Évolution du nombre d’interactions par année'}, xlabel='year'>

# %% [markdown]
# Le nombre d’interactions (avis) augmente progressivement entre 1999 et 2012, puis connaît une forte accélération entre 2013 et 2015, période où l’activité des utilisateurs est à son maximum. À partir de 2016, on observe une chute marquée du volume d’interactions, ce qui traduit une baisse globale de l’activité d’avis dans ce dataset.

# %% [markdown]
# **Nombre de nœuds par année**

# %%
df_stats.plot(x='year', y='nodes', kind='line', title='Évolution du nombre de nœuds')
# Out:
# <Axes: title={'center': 'Évolution du nombre de nœuds'}, xlabel='year'>

# %% [markdown]
# Le nombre de nœuds augmente régulièrement chaque année jusqu’en 2015, ce qui reflète à la fois l’arrivée de nouveaux utilisateurs et l’élargissement du catalogue de jeux. L’année 2015 marque le point culminant du réseau. Après cette date, le nombre de nœuds diminue fortement, indiquant une réduction de l’activité ou du volume d’avis présents dans ce dataset.

# %% [markdown]
# **Densité**

# %%
df_stats.plot(x='year', y='density', kind='line', title='Évolution de la densité du réseau')
# Out:
# <Axes: title={'center': 'Évolution de la densité du réseau'}, xlabel='year'>

# %% [markdown]
# La densité du réseau baisse fortement au fil des années. Cela signifie que le réseau s’agrandit beaucoup plus vite que le nombre d’interactions entre utilisateurs et jeux. Ce comportement est typique des grands réseaux utilisateur–produit, où chaque utilisateur ne se connecte qu’à une petite partie du catalogue. Après 2017, la densité remonte légèrement, car le réseau se réduit en taille

# %% [markdown]
# ##Construire un système de recommandation basé sur le graphe

# %%
# !pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.12/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from python-louvain) (3.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from python-louvain) (2.0.2)

# %% [markdown]
# **Projection année par année**

# %%
from networkx.algorithms import bipartite
import community as community_louvain

def get_game_graph_for_year(year):
    # extraire le sous-dataset
    df_y = df[df['year'] == year]

    # construire le bipartite pour cette année
    B_y = nx.Graph()

    users_y = df_y['reviewerID'].unique()
    games_y = df_y['asin'].unique()

    B_y.add_nodes_from(users_y, bipartite='user')
    B_y.add_nodes_from(games_y, bipartite='game')

    edges = list(zip(df_y['reviewerID'], df_y['asin']))
    B_y.add_edges_from(edges)

    # projection : jeux seulement
    G_games = bipartite.weighted_projected_graph(B_y, games_y)

    return G_games

# %% [markdown]
# **Appliquer Louvain pour une année**

# %%
import community.community_louvain as community_louvain

# %%
G_2010 = get_game_graph_for_year(2010)

partition_2010 = community_louvain.best_partition(G_2010)
len(partition_2010)
# Out:
# 4236

# %% [markdown]
# **Nombre total des communautés**

# %%
num_communities = len(set(partition_2010.values()))
num_communities
# Out:
# 449

# %% [markdown]
# **Les 5 premiers communautés**

# %%
from collections import defaultdict

communities_2010 = defaultdict(list)

for game, com in partition_2010.items():
    communities_2010[com].append(game)

for c, games_list in list(communities_2010.items())[:5]:
    print(f"Communauté {c} : {len(games_list)} jeux")
# Out:
# Communauté 0 : 221 jeux
# Communauté 24 : 449 jeux
# Communauté 2 : 1 jeux
# Communauté 194 : 400 jeux
# Communauté 108 : 85 jeux

# %% [markdown]
# L’année 2010 présente une structure communautaire riche, avec 448 communautés détectées par l’algorithme de Louvain.
# Les plus grandes regroupent entre 230 et 455 jeux, révélant l’existence de genres populaires fortement connectés.
# Des micro-communautés existent également (taille 1 à 5 jeux), ce qui montre que certains jeux sont très spécifiques dans leurs audiences.

# %% [markdown]
# ##Louvain dynamique : toutes les années

# %%
import community.community_louvain as community_louvain
from networkx.algorithms import bipartite
from collections import defaultdict

years = sorted(df['year'].unique())
all_partitions = {}
all_stats = []

def get_game_graph_for_year(year):
    df_y = df[df['year'] == year]

    B_y = nx.Graph()
    users_y = df_y['reviewerID'].unique()
    games_y = df_y['asin'].unique()

    B_y.add_nodes_from(users_y, bipartite='user')
    B_y.add_nodes_from(games_y, bipartite='game')

    edges = list(zip(df_y['reviewerID'], df_y['asin']))
    B_y.add_edges_from(edges)

    G_games = bipartite.weighted_projected_graph(B_y, games_y)
    return G_games


for year in years:
    G_y = get_game_graph_for_year(year)

    if G_y.number_of_nodes() < 5:
        continue

    partition_y = community_louvain.best_partition(G_y)

    all_partitions[year] = partition_y

    num_comm = len(set(partition_y.values()))
    nb_games = len(partition_y)

    all_stats.append({
        "year": year,
        "nb_games": nb_games,
        "nb_communities": num_comm
    })

    print(f"Année {year} : {nb_games} jeux, {num_comm} communautés détectées")
# Out:
# Année 1999 : 60 jeux, 24 communautés détectées
# Année 2000 : 619 jeux, 36 communautés détectées
# Année 2001 : 1200 jeux, 37 communautés détectées
# Année 2002 : 1528 jeux, 56 communautés détectées
# Année 2003 : 1754 jeux, 69 communautés détectées
# Année 2004 : 1875 jeux, 102 communautés détectées
# Année 2005 : 2168 jeux, 123 communautés détectées
# Année 2006 : 2198 jeux, 146 communautés détectées
# Année 2007 : 2811 jeux, 244 communautés détectées
# Année 2008 : 3366 jeux, 253 communautés détectées
# Année 2009 : 4088 jeux, 306 communautés détectées
# Année 2010 : 4236 jeux, 447 communautés détectées
# Année 2011 : 4928 jeux, 518 communautés détectées
# Année 2012 : 6197 jeux, 464 communautés détectées
# Année 2013 : 8703 jeux, 323 communautés détectées
# Année 2014 : 10874 jeux, 259 communautés détectées
# Année 2015 : 12164 jeux, 220 communautés détectées
# Année 2016 : 11347 jeux, 281 communautés détectées
# Année 2017 : 8792 jeux, 405 communautés détectées
# Année 2018 : 4734 jeux, 620 communautés détectées

# %% [markdown]
# Nous observons trois grandes phases dans l’évolution des communautés du réseau :
#
# une phase d’émergence (1999–2004) avec peu de jeux et des communautés petites,
#
# une phase de croissance (2005–2012) où le réseau se structure et voit apparaître de nombreuses communautés,
#
# une phase de maturation suivie d’un éclatement (2013–2018) où, malgré une baisse du volume de jeux, le nombre de communautés augmente à nouveau, traduisant une fragmentation des goûts des utilisateurs.

# %% [markdown]
# **Mettre les statistiques dans un DataFrame**

# %%
df_comm = pd.DataFrame(all_stats)
df_comm
# Out:
#     year  nb_games  nb_communities
# 0   1999        60              24
# 1   2000       619              36
# 2   2001      1200              37
# 3   2002      1528              56
# 4   2003      1754              69
# 5   2004      1875             102
# 6   2005      2168             123
# 7   2006      2198             146
# 8   2007      2811             244
# 9   2008      3366             253
# 10  2009      4088             306
# 11  2010      4236             447
# 12  2011      4928             518
# 13  2012      6197             464
# 14  2013      8703             323
# 15  2014     10874             259
# 16  2015     12164             220
# 17  2016     11347             281
# 18  2017      8792             405
# 19  2018      4734             620

# %% [markdown]
# **Visualisation de l’évolution**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df_comm['year'], df_comm['nb_communities'], marker='o')
plt.title("Évolution du nombre de communautés (1999–2018)")
plt.xlabel("Année")
plt.ylabel("Nombre de communautés")
plt.grid(True)
plt.show()

# %% [markdown]
# Le nombre de communautés augmente régulièrement de 1999 à 2011, période correspondant à la forte croissance de la plateforme. À partir de 2012, le réseau devient plus dense et les communautés se regroupent, ce qui explique la baisse temporaire du nombre de clusters. Après 2015, le nombre de communautés remonte fortement, traduisant une fragmentation du réseau et des préférences plus diversifiées chez les utilisateurs.

# %%
G_2015 = get_game_graph_for_year(2015)

# %%
partition_2015 = all_partitions[2015]

# %%
def recommend_for_game(game_id, G_year, partition_year, top_n=10):

    if game_id not in partition_year:
        return f"⚠️ Le jeu {game_id} n'existe pas dans cette année."

    comm = partition_year[game_id]

    same_comm_games = [g for g, c in partition_year.items() if c == comm]

    same_comm_games.remove(game_id)

    sorted_games = sorted(same_comm_games,
                          key=lambda g: G_year.degree(g),
                          reverse=True)

    return sorted_games[:top_n]

# %%
import random

game_2015_sample = random.choice(list(partition_2015.keys()))
game_2015_sample
# Out:
# 'B001TOQ8KC'

# %%
recommend_for_game(game_2015_sample, G_2015, partition_2015)
# Out:
# ['B00DD0B0BM',
#  'B00PB9LZQI',
#  'B00DC7G2W8',
#  'B00DD0B1R0',
#  'B00MUY0OFU',
#  'B00KWFCV32',
#  'B00KWEHBAG',
#  'B00N4ABT1C',
#  'B0053BCO00',
#  'B00DC7G0GG']

# %%
G_2015 = get_game_graph_for_year(2015)
partition_2015 = all_partitions[2015]

# %%
game_2015_sample = random.choice(list(partition_2015.keys()))
game_2015_sample
# Out:
# 'B00004UE2A'

# %%
recommend_for_game(game_2015_sample, G_2015, partition_2015)
# Out:
# ['B000TLU67W',
#  'B00004YRQA',
#  'B000P46NKC',
#  'B000F5IH2I',
#  'B00269DX5W',
#  'B00JA81WQE',
#  'B001TOMR6Q',
#  'B00KX7672U',
#  'B00002DHEV',
#  'B0009XBWY6']

# %% [markdown]
# Pour l’année 2015, Louvain détecte que le jeu B001UU1WLA appartient à une communauté regroupant des jeux appréciés par un même groupe d’utilisateurs.
# Les jeux recommandés sont les titres les plus populaires de cette communauté, donc ceux que les joueurs ayant des goûts similaires ont tendance à apprécier également.

# %% [markdown]
# **recommandation utilisateur (année 2015)**

# %%
def recommend_for_user(user_id, df_year, G_year, partition_year, top_n=10):

    if user_id not in df_year['reviewerID'].values:
        return f"⚠️ L'utilisateur {user_id} n'a pas d'activité dans cette année."

    user_games = df_year[df_year['reviewerID'] == user_id]['asin'].unique()

    game_communities = [partition_year[g] for g in user_games if g in partition_year]

    if len(game_communities) == 0:
        return "⚠️ Impossible de déterminer la communauté principale."

    from collections import Counter
    dominant_comm = Counter(game_communities).most_common(1)[0][0]

    comm_games = [g for g, c in partition_year.items() if c == dominant_comm]

    sorted_games = sorted(comm_games, key=lambda g: G_year.degree(g), reverse=True)

    final_recs = [g for g in sorted_games if g not in user_games]

    return final_recs[:top_n]

# %% [markdown]
# -**Extraire le dataset de 2015**

# %%
df_2015 = df[df['year'] == 2015]

# %% [markdown]
# **Choisir un utilisateur réel de 2015**

# %%
user_2015_sample = random.choice(df_2015['reviewerID'].unique())
user_2015_sample
# Out:
# 'A2LDFT6VJ7SSA0'

# %% [markdown]
# **Tester la recommandation**

# %%
recommend_for_user(user_2015_sample, df_2015, G_2015, partition_2015)
# Out:
# ['B00BGA9WK2',
#  'B00BI83EVU',
#  'B00KVR4HEC',
#  'B00ENFVJJO',
#  'B00JK00S0S',
#  'B00KAED850',
#  'B00D2ZK1IG',
#  'B00WTI3JPE',
#  'B00DBLBMBQ',
#  'B00BGA9Y3W']

# %% [markdown]
# Pour l’année 2015, nous avons généré des recommandations personnalisées en identifiant la communauté dominante de chaque utilisateur à partir des jeux qu’il a notés. Les jeux les plus populaires de cette communauté (et qu'il n’a pas encore notés) sont proposés comme recommandations pertinentes

# %% [markdown]
# ##Recommandation globale par communauté

# %% [markdown]
# **Top communautés (par taille) pour une année**

# %%
G_2015 = get_game_graph_for_year(2015)
partition_2015 = all_partitions[2015]

# %%
from collections import Counter

def get_top_communities(partition, top_k=5):
    comm_counts = Counter(partition.values())
    return comm_counts.most_common(top_k)

top_comms_2015 = get_top_communities(partition_2015, top_k=5)
top_comms_2015
# Out:
# [(2, 2272), (6, 1958), (1, 1823), (4, 1798), (0, 1192)]

# %% [markdown]
# **Top jeux dans une communauté (par popularité)**

# %%
def top_games_in_community(comm_id, partition_year, G_year, top_n=10):
    games_in_comm = [g for g, c in partition_year.items() if c == comm_id]

    games_sorted = sorted(
        games_in_comm,
        key=lambda g: G_year.degree(g),
        reverse=True
    )

    return games_sorted[:top_n]

# %% [markdown]
# **Utilisation concrète pour 2015**

# %%
for comm_id, size in top_comms_2015:
    print(f"\n🌐 Communauté {comm_id} – {size} jeux")
    top_games = top_games_in_community(comm_id, partition_2015, G_2015, top_n=5)
    print("Top jeux de cette communauté :", top_games)
# Out:
# 🌐 Communauté 2 – 2272 jeux
# Top jeux de cette communauté : ['B00DD0B0BM', 'B00PB9LZQI', 'B00DC7G2W8', 'B00DD0B1R0', 'B00MUY0OFU']
#
# 🌐 Communauté 6 – 1958 jeux
# Top jeux de cette communauté : ['B000TLU67W', 'B00004YRQA', 'B000P46NKC', 'B000F5IH2I', 'B00269DX5W']
#
# 🌐 Communauté 1 – 1823 jeux
# Top jeux de cette communauté : ['B00BGA9WK2', 'B00BI83EVU', 'B00KVR4HEC', 'B00ENFVJJO', 'B00Z7V9P8K']
#
# 🌐 Communauté 4 – 1798 jeux
# Top jeux de cette communauté : ['B003ZSP0WW', 'B0050SYILE', 'B00BU3ZLJQ', 'B000FRU0NU', 'B002BSA20M']
#
# 🌐 Communauté 0 – 1192 jeux
# Top jeux de cette communauté : ['B00KME8JBQ', 'B00JF63SQI', 'B00JJNQG98', 'B00MYTSDU4', 'B00KAED6Y8']

# %% [markdown]
# En 2015, l’application de l’algorithme de Louvain met en évidence une segmentation claire du réseau en plusieurs macro-communautés.
# La communauté principale rassemble 2026 jeux, tandis que les quatre suivantes regroupent entre 1110 et 1647 titres.
# L’analyse des degrés montre que certaines œuvres occupent un rôle central dans chacune de ces communautés : elles correspondent aux jeux les plus connectés du réseau et structurent les préférences des utilisateurs.
# Ces jeux ‘centraux’ constituent la base naturelle d’un système de recommandation fondé sur les interactions du graphe.

# %% [markdown]
# #Préparer les graphes et les partitions pour toutes les années

# %%
# Construction des graphes jeu–jeu pour chaque année
all_graphs = {}

for y in sorted(df['year'].unique()):
    df_y = df[df['year'] == y]

    G = nx.Graph()

    # On ajoute les edges jeu-jeu via les utilisateurs
    for user, games in df_y.groupby('reviewerID')['asin']:
        games = list(games)
        for i in range(len(games)):
            for j in range(i+1, len(games)):
                G.add_edge(games[i], games[j])

    all_graphs[y] = G

print("✔️ all_graphs créé.")
# Out:
# ✔️ all_graphs créé.

# %% [markdown]
# Pour analyser l’évolution du réseau, nous générons un graphe distinct pour chaque année. Pour cela, nous regroupons les jeux notés par chaque utilisateur dans une année donnée et nous créons une arête entre deux jeux lorsqu’ils ont été co-consultés par ce même utilisateur. Ce principe de projection bipartite nous permet de construire un réseau jeu–jeu représentatif des comportements d’achat ou de notation de cette période.

# %% [markdown]
# **Créer all_partitions (communautés Louvain pour chaque année)**

# %%
import community.community_louvain as community_louvain

all_partitions = {}

for y in all_graphs:
    G = all_graphs[y]

    if len(G.nodes()) > 0:
        partition = community_louvain.best_partition(G)
        all_partitions[y] = partition
    else:
        all_partitions[y] = {}

print("✔️ all_partitions créé.")
# Out:
# ✔️ all_partitions créé.

# %% [markdown]
# Pour chaque graphe annuel, nous appliquons l’algorithme de Louvain qui permet de partitionner le réseau en communautés. Chaque partition associe à chaque jeu un numéro de communauté, révélant la structure interne du réseau pour l’année concernée

# %% [markdown]
# **Vérification du résultat**

# %%
all_graphs
# Out:
# {np.int64(1999): <networkx.classes.graph.Graph at 0x7d91a1c35b20>,
#  np.int64(2000): <networkx.classes.graph.Graph at 0x7d91b83497c0>,
#  np.int64(2001): <networkx.classes.graph.Graph at 0x7d91b83a1700>,
#  np.int64(2002): <networkx.classes.graph.Graph at 0x7d91a1dcb770>,
#  np.int64(2003): <networkx.classes.graph.Graph at 0x7d91a1d7df10>,
#  np.int64(2004): <networkx.classes.graph.Graph at 0x7d91b81f09e0>,
#  np.int64(2005): <networkx.classes.graph.Graph at 0x7d91b8237230>,
#  np.int64(2006): <networkx.classes.graph.Graph at 0x7d91a1d7c7a0>,
#  np.int64(2007): <networkx.classes.graph.Graph at 0x7d91a1c34290>,
#  np.int64(2008): <networkx.classes.graph.Graph at 0x7d91a1c35c70>,
#  np.int64(2009): <networkx.classes.graph.Graph at 0x7d91a1c36840>,
#  np.int64(2010): <networkx.classes.graph.Graph at 0x7d91a1c35a60>,
#  np.int64(2011): <networkx.classes.graph.Graph at 0x7d91a1c35400>,
#  np.int64(2012): <networkx.classes.graph.Graph at 0x7d91a1c35a30>,
#  np.int64(2013): <networkx.classes.graph.Graph at 0x7d91a1c35be0>,
#  np.int64(2014): <networkx.classes.graph.Graph at 0x7d91a1c34560>,
#  np.int64(2015): <networkx.classes.graph.Graph at 0x7d91a1c34b90>,
#  np.int64(2016): <networkx.classes.graph.Graph at 0x7d91a1c35940>,
#  np.int64(2017): <networkx.classes.graph.Graph at 0x7d91a1c361b0>,
#  np.int64(2018): <networkx.classes.graph.Graph at 0x7d91a1c34b30>}

# %%
all_partitions
# Out:
# {np.int64(1999): {'B00001LDCK': 1,
#   'B00001IVLY': 1,
#   'B00001IVR9': 1,
#   'B00001NTSO': 1,
#   'B00002CF94': 2,
#   'B00002EPY0': 2,
#   'B00002S7YE': 2,
#   'B00000K1V2': 3,
#   'B000021Y5F': 3,
#   'B000021Y5Q': 3,
#   'B000021Y5V': 3,
#   'B000038AB3': 3,
#   'B000038AAS': 3,
#   'B00000K4EC': 4,
#   'B00000K4TQ': 4,
#   'B00001KUII': 4,
#   'B00001IVRD': 4,
#   'B00000K4MC': 4,
#   'B00003OPCY': 4,
#   'B00000K1VE': 5,
#   'B0000296O5': 5,
#   'B00002EPY1': 1,
#   'B00002NDRY': 1,
#   'B00000G16I': 4,
#   'B00000JDFT': 2,
#   'B00002STNQ': 2,
#   'B00000DMAM': 1,
#   'B00000DMAD': 1,
#   'B00000K4AX': 1,
#   'B00001QEQ8': 1,
#   'B00001W0J2': 1,
#   'B00004KDF9': 1,
#   'B00004SWKG': 1,
#   'B00001IVB4': 6,
#   'B00002CF9G': 6,
#   'B00000DMAN': 1,
#   'B00000JL6V': 0,
#   'B000021XYY': 0,
#   'B00001NFRQ': 1,
#   'B00002EPYE': 1,
#   'B00001IVGE': 1,
#   'B00001XDKO': 2,
#   'B00002STNP': 2},
#  np.int64(2000): {'B00000J2W7': 0,
#   'B00002ST27': 0,
#   'B00004U5VS': 1,
#   'B00004UFRD': 1,
#   'B00004W4WH': 1,
#   'B00004WYR7': 2,
#   'B00004YC3N': 1,
#   'B00004YKHW': 3,
#   'B00002SU5A': 4,
#   'B00003031F': 4,
#   'B00004W4WI': 4,
#   'B0000524PF': 4,
#   'B000056BSY': 4,
#   'B00000G16I': 2,
#   'B00002SU5D': 3,
#   'B0000296NT': 1,
#   'B00004SR5M': 1,
#   'B00004SWL9': 5,
#   'B00004T4XI': 6,
#   'B00004TBGT': 1,
#   'B00004TC6E': 7,
#   'B00000K2YD': 4,
#   'B00000K4EC': 4,
#   'B00000K50S': 4,
#   'B00001IVRD': 4,
#   'B00001LDCK': 4,
#   'B0000296ZP': 4,
#   'B00002EPYV': 4,
#   'B00002EPYY': 4,
#   'B00002EPYI': 4,
#   'B00004T77G': 1,
#   'B00004YLZM': 8,
#   'B00000DMA8': 8,
#   'B00000K4MC': 3,
#   'B00003O9KY': 4,
#   'B00003OPES': 8,
#   'B00004DITI': 8,
#   'B00002CF8V': 8,
#   'B00004C8SJ': 8,
#   'B00004WFVZ': 8,
#   'B00000DMAM': 4,
#   'B00000K4AX': 4,
#   'B00001QEQ8': 4,
#   'B00001QEQA': 4,
#   'B00004KDF9': 4,
#   'B00004RFBE': 4,
#   'B00004ZASP': 4,
#   'B00004ZBO4': 4,
#   'B00000K10U': 6,
#   'B00004S99R': 5,
#   'B0000296O5': 3,
#   'B00004RBQX': 7,
#   'B00004S99O': 1,
#   'B00004T4XK': 1,
#   'B00004U3GL': 1,
#   'B00004U5VN': 1,
#   'B00004WKN9': 1,
#   'B00004WLMA': 1,
#   'B00004Y57G': 5,
#   'B00004YKHS': 3,
#   'B00001XDKO': 4,
#   'B00004TJCL': 1,
#   'B00000K2Y6': 4,
#   'B00001IVB6': 8,
#   'B00000DMB3': 0,
#   'B00000JRSB': 2,
#   'B00000K125': 5,
#   'B00000K2R4': 3,
#   'B00000K3X9': 5,
#   'B00002R28C': 5,
#   'B0000488VP': 5,
#   'B00001OPJD': 0,
#   'B00001OX3S': 0,
#   'B00001P4QN': 8,
#   'B00002CF9M': 8,
#   'B00004TNDY': 1,
#   'B00004U5VF': 1,
#   'B00004YRQ9': 1,
#   'B000051WA5': 3,
#   'B0000520GG': 1,
#   'B00001KUII': 4,
#   'B00001IVLY': 4,
#   'B000040OEH': 4,
#   'B00004NS0Z': 4,
#   'B00000DMAT': 3,
#   'B00000J9JI': 3,
#   'B00002R28F': 3,
#   'B00001XDTY': 8,
#   'B00004KD64': 3,
#   'B00004SWLZ': 7,
#   'B00004XOM2': 7,
#   'B00001ZUGO': 1,
#   'B00002STKO': 1,
#   'B00004TKMB': 1,
#   'B00004U5VP': 1,
#   'B00004VWGR': 1,
#   'B00004W4S3': 1,
#   'B0000522AC': 3,
#   'B00004S99S': 5,
#   'B00000K3XB': 1,
#   'B00004WMVK': 1,
#   'B00001R3XA': 8,
#   'B00002SUR0': 8,
#   'B00004NHFD': 4,
#   'B00004LN2T': 6,
#   'B00004R9IN': 3,
#   'B00000ID60': 0,
#   'B00000J97G': 4,
#   'B00000K2G9': 0,
#   'B00002ST2M': 0,
#   'B00004S99X': 0,
#   'B00004S9AA': 0,
#   'B00004U358': 0,
#   'B000056BR4': 0,
#   'B00000K1VA': 7,
#   'B00001X5C3': 1,
#   'B00004R9IB': 0,
#   'B00004T1M7': 8,
#   'B00001NTSO': 8,
#   'B00004C8SI': 3,
#   'B00004DITJ': 8,
#   'B00001YVBL': 8,
#   'B00002NDRY': 8,
#   'B00002STKN': 8,
#   'B00004R9IG': 7,
#   'B00004U4R9': 3,
#   'B00004VP4B': 1,
#   'B00004VP4M': 8,
#   'B00004W4QS': 1,
#   'B00004Y7SY': 8,
#   'B00001LDCD': 2,
#   'B00001IVR9': 2,
#   'B00001SHNG': 2,
#   'B00004SPW9': 2,
#   'B00004U3BX': 2,
#   'B00004VXAZ': 2,
#   'B0000296ZN': 3,
#   'B00004U8K3': 3,
#   'B00000J9J9': 0,
#   'B00000K2G7': 5,
#   'B000031KJM': 0,
#   'B00003OTI3': 0,
#   'B000050FBJ': 0,
#   'B00002STGV': 4,
#   'B00004NS01': 6,
#   'B00004OCYG': 4,
#   'B000021XYX': 0,
#   'B00002ST4X': 0,
#   'B00002STGD': 3,
#   'B000031KJX': 8,
#   'B00004YZ91': 0,
#   'B00001NFSY': 0,
#   'B00004RC1Y': 6,
#   'B00000DMAO': 0,
#   'B00000DMAQ': 0,
#   'B00001OX4T': 0,
#   'B00001X50Y': 0,
#   'B00001ZWP8': 3,
#   'B00002SVG7': 0,
#   'B00004SWLT': 3,
#   'B00004U1R0': 0,
#   'B00004U620': 0,
#   'B00004U9K8': 0,
#   'B00004VP44': 0,
#   'B00004U5VV': 1,
#   'B00004YMZS': 1,
#   'B000051WA3': 1,
#   'B00000K4DE': 7,
#   'B00001LDC8': 7,
#   'B00002STNQ': 4,
#   'B00004SWKG': 7,
#   'B00002971H': 0,
#   'B00002SV0U': 1,
#   'B00000JL6V': 4,
#   'B00001QHYE': 4,
#   'B00001SVE2': 4,
#   'B00002EIZN': 4,
#   'B00004C8S2': 4,
#   'B00004T1MD': 4,
#   'B00001IVB4': 4,
#   'B00000K3QV': 4,
#   'B00001XDTK': 4,
#   'B00002EPY0': 4,
#   'B00002NDSI': 4,
#   'B00002STOB': 1,
#   'B00002STH5': 3,
#   'B00000JNHJ': 2,
#   'B00001QEEC': 7,
#   'B0000296ZD': 7,
#   'B00004KHB4': 8,
#   'B00004OCYH': 7,
#   'B00004SWM0': 7,
#   'B00004U4R4': 7,
#   'B00004UE0V': 7,
#   'B00004ZB7E': 7,
#   'B00000IZ7Q': 4,
#   'B000028U20': 1,
#   'B00004DSDE': 4,
#   'B00004KHB7': 8,
#   'B00002EPZ2': 4,
#   'B00004SRF5': 3,
#   'B00002SU53': 3,
#   'B00004KHB0': 4,
#   'B00004R9AL': 4,
#   'B00004T77A': 7,
#   'B00004TFLJ': 8,
#   'B00004TJDL': 7,
#   'B00004U1QY': 3,
#   'B00004XOM1': 7,
#   'B00004YMZV': 7,
#   'B000053VWB': 5,
#   'B00000I1BB': 0,
#   'B00000I1BF': 2,
#   'B00000IYEQ': 4,
#   'B0000296ZJ': 0,
#   'B00002AH2T': 0,
#   'B00002STQV': 0,
#   'B00001NFRB': 4,
#   'B00002SUPP': 4,
#   'B00002EPYC': 3,
#   'B00002DHEV': 0,
#   'B00000K1VC': 1,
#   'B00000K4TQ': 1,
#   'B000035YA1': 1,
#   'B000051WA6': 1,
#   'B00000DMAE': 4,
#   'B00001ZT7T': 4,
#   'B00001YVIB': 4,
#   'B00004YMZT': 3,
#   'B00004R8WH': 10,
#   'B0000524NL': 10,
#   'B00002CF81': 8,
#   'B00002EPY1': 4,
#   'B00004T4XM': 5,
#   'B00004U1PK': 6,
#   'B00004RFB9': 6,
#   'B00004TTTQ': 6,
#   'B00002STWP': 0,
#   'B00002STW1': 0,
#   'B00004TCT3': 0,
#   'B00004TEYR': 0,
#   'B00004YSWK': 0,
#   'B00002STWU': 0,
#   'B00001LCDP': 4,
#   'B00001LCDF': 4,
#   'B00004RIPJ': 8,
#   'B00000I1BG': 2,
#   'B00004R8XR': 2,
#   'B00004RBQQ': 2,
#   'B00004S9AF': 3,
#   'B00004U47F': 1,
#   'B00004U627': 1,
#   'B00004UFRI': 1,
#   'B00002CF5W': 8,
#   'B00002970G': 0,
#   'B00002970R': 0,
#   'B00002EPGW': 0,
#   'B000029706': 2,
#   'B00002SVJU': 0,
#   'B000035YBP': 0,
#   'B00004S1DZ': 0,
#   'B00004U1QX': 2,
#   'B00002STUB': 0,
#   'B00002EPY6': 8,
#   'B00002EPYA': 2,
#   'B00002S6BL': 8,
#   'B00002CF8U': 8,
#   'B00000ID61': 3,
#   'B00000IKCG': 3,
#   'B00002STGM': 3,
#   'B00002STGL': 3,
#   'B00002STFH': 3,
#   'B00002STFD': 3,
#   'B00004RBOK': 4,
#   'B00002STHV': 5,
#   'B0000488VQ': 5,
#   'B00004U4QB': 5,
#   'B00004WESW': 5,
#   'B000035YC5': 1,
#   'B00004YUBX': 1,
#   'B00000K4D4': 0,
#   'B00002STEZ': 0,
#   'B00004S3AI': 4,
#   'B00004W4QV': 1,
#   'B00004ZCP0': 1,
#   'B00000I1BZ': 2,
#   'B00000IODY': 2,
#   'B00000K39I': 2,
#   'B000021Y5P': 2,
#   'B00001ZWMV': 2,
#   'B00002DHER': 2,
#   'B00002STJG': 2,
#   'B00002STPF': 2,
#   'B000034DCF': 2,
#   'B000038ABO': 2,
#   'B000038IFX': 2,
#   'B00004SPRD': 2,
#   'B00001OWYW': 5,
#   'B00002SVX6': 3,
#   'B000034DBS': 3,
#   'B00004UG9B': 3,
#   'B00004U55D': 8,
#   'B00004U5VE': 5,
#   'B00004YRVW': 1,
#   'B000028U28': 7,
#   'B00002SU5C': 4,
#   'B000038A7Q': 6,
#   'B000056EZG': 6,
#   'B000038A6U': 3,
#   'B00000DMAX': 0,
#   'B00000INR2': 3,
#   'B00002EPYE': 4,
#   'B000046Q7Q': 0,
#   'B000021Y5F': 11,
#   'B000021Y56': 11,
#   'B000021Y5C': 11,
#   'B00000DMAA': 4,
#   'B00000DMAD': 4,
#   'B00000K2XJ': 4,
#   'B00001LAE2': 4,
#   'B00001NFUA': 4,
#   'B000021XYY': 4,
#   'B00002S9O4': 4,
#   'B00004T00A': 4,
#   'B00004WGW1': 4,
#   'B00004WGVX': 4,
#   'B00004XRBM': 4,
#   'B00000K1AF': 3,
#   'B00000IWIW': 4,
#   'B00000JDFT': 8,
#   'B00000K57S': 4,
#   'B00002CF94': 4,
#   'B00002S6CC': 4,
#   'B00004ZB2I': 4,
#   'B00000DMAH': 8,
#   'B00001SVI8': 8,
#   'B00002NDRR': 8,
#   'B00004S3AH': 8,
#   'B00004UE0I': 8,
#   'B00004UE0U': 8,
#   'B00001N2OM': 8,
#   'B00001XDK9': 8,
#   'B00002CF9G': 8,
#   'B00002SVBZ': 8,
#   'B00003OPCY': 8,
#   'B00004KHDN': 3,
#   'B00004TJ2N': 8,
#   'B00004U55G': 8,
#   'B00004UE0E': 8,
#   'B00002CF96': 4,
#   'B00002SV6G': 4,
#   'B00002CF98': 12,
#   'B00002K13U': 12,
#   'B00004WI4E': 12,
#   'B00004NS10': 12,
#   'B00000K50Z': 6,
#   'B000031KJQ': 6,
#   'B0000488VR': 6,
#   'B00004KHBO': 6,
#   'B00004KHAG': 6,
#   'B00004RGJE': 8,
#   'B00004WGVY': 6,
#   'B00004XONQ': 6,
#   'B00002SUOW': 6,
#   'B00001XDUB': 8,
#   'B00004S653': 8,
#   'B00003IF3G': 4,
#   'B00000K4C9': 1,
#   'B00004U5VU': 1,
#   'B00004U62Q': 1,
#   'B00004UFFP': 5,
#   'B00004YRQA': 1,
#   'B000050ZEN': 1,
#   'B00002NDR7': 4,
#   'B000051SGS': 7,
#   'B00000DMB4': 0,
#   'B00000F1GM': 3,
#   'B00000IFRI': 8,
#   'B00001ZT9E': 7,
#   'B00001QEQ9': 4,
#   'B00000JHPD': 0,
#   'B00002ST5S': 0,
#   'B000046S3Z': 0,
#   'B00004SWLY': 7,
#   'B00004TTID': 5,
#   'B00001LDCC': 0,
#   'B00000IKQH': 3,
#   'B00002STGN': 3,
#   'B00002STH2': 3,
#   'B000034DML': 3,
#   'B00004TJE5': 3,
#   'B000056FLI': 3,
#   'B0000296ZB': 8,
#   'B00004VP46': 8,
#   'B00002STKG': 6,
#   'B00000K1V9': 7,
#   'B00001ZUGT': 7,
#   'B00004U8KL': 1,
#   'B00001ZT4A': 4,
#   'B00000K4CZ': 8,
#   'B00004WHW7': 8,
#   'B00001ZT47': 4,
#   'B00002EPYJ': 8,
#   'B00004W419': 8,
#   'B0000522CC': 8,
#   'B00000K1VE': 7,
#   'B00001ZUOY': 7,
#   'B00004KHB3': 4,
#   'B00004UE0K': 8,
#   'B00000DMAN': 4,
#   'B00004SV21': 4,
#   'B00000K5D8': 4,
#   'B00001ZWOP': 4,
#   'B00002EIZS': 4,
#   'B00002STIE': 4,
#   'B00004T1MG': 4,
#   'B00001IVGE': 4,
#   'B00001ZULE': 1,
#   'B00004TEXU': 1,
#   'B00000K1V2': 5,
#   'B000006OVE': 2,
#   'B00000DMAP': 2,
#   'B00004YNVG': 1,
#   'B00004YRQD': 1,
#   'B00000J2OO': 0,
#   'B00001ZWPX': 0,
#   'B00002971O': 0,
#   'B00000K4E1': 0,
#   'B00001WQHT': 0,
#   'B00002STFJ': 0,
#   'B00004T4XO': 1,
#   'B00004TEXF': 1,
#   'B00004U5X1': 1,
#   'B00000T94P': 13,
#   'B00001ZWNA': 13,
#   'B00004R9FG': 13,
#   'B00000I1BT': 3,
#   'B00001TZYD': 3,
#   'B000021Y5S': 3,
#   'B00004XOXL': 3,
#   'B00002STPG': 2,
#   'B00004SZ9Z': 8,
#   'B00000J96V': 0,
#   'B00000K1VG': 0,
#   'B00001QED2': 0,
#   'B00004R9IC': 0,
#   'B00000I1BY': 5,
#   'B000034DMG': 7,
#   'B00004LN2V': 7,
#   'B000046S40': 0,
#   'B000047GEI': 0,
#   'B00004U5IF': 0,
#   'B00004W4VH': 1,
#   'B00004OCXR': 8,
#   'B00004W4S2': 5,
#   'B00004TBC0': 4,
#   'B00004SQP5': 1,
#   'B000028U2E': 1,
#   'B00001T37S': 5,
#   'B00004U3CR': 3,
#   'B00004W4QG': 1,
#   'B00001X50L': 5,
#   'B00000K3DM': 4,
#   'B00001ZT77': 4,
#   'B00000F1GI': 12,
#   'B00001NFS5': 8,
#   'B00002STLK': 8,
#   'B00004U55B': 8,
#   'B00000I1BQ': 2,
#   'B00004TBGX': 5,
#   'B00000K4ST': 0,
#   'B00004S9A0': 0,
#   'B00004TEXR': 0,
#   'B00004TFJC': 0,
#   'B00004U5VJ': 0,
#   'B00002SVP4': 0,
#   'B00002SX0E': 4,
#   'B00002STNP': 4,
#   'B00000JIUG': 5,
#   'B00004XOLO': 5,
#   'B00001R3XK': 4,
#   'B00001W0J2': 8,
#   'B00004U8KR': 4,
#   'B00004WHWG': 8,
#   'B000006P0K': 1,
#   'B000006RGS': 1,
#   'B000006RGO': 1,
#   'B00001XDK5': 1,
#   'B00002SU8L': 1,
#   'B00000IPEE': 7,
#   'B00000K2R5': 7,
#   'B00002STPM': 7,
#   'B00002STPN': 7,
#   'B00004Y7ZO': 8,
#   'B00002Z72E': 4,
#   'B00004ZC7H': 4,
#   'B00002STGZ': 0,
#   'B00000JL60': 4,
#   'B00004TH9E': 4,
#   'B00000DMB2': 0,
#   'B00000K2GI': 9,
#   'B00002STFC': 9,
#   'B00004U8H1': 3,
#   'B00004U8GM': 4,
#   'B00002SV4N': 2,
#   'B00004U8RC': 1,
#   'B0000302P8': 4,
#   'B00004WMVL': 2,
#   'B00004YMZY': 5,
#   'B00000DMAR': 2,
#   'B00000I1BK': 2,
#   'B00000I1BR': 2,
#   'B000031KJL': 2,
#   'B000034DC2': 2,
#   'B00004S9AD': 2,
#   'B00004YB5U': 2,
#   'B00004SPY0': 2,
#   'B00004S4YD': 2,
#   'B00004NHFO': 8,
#   'B00000PLUW': 3,
#   'B00001SHON': 3,
#   'B00004YKHU': 3,
#   'B00002STQE': 1,
#   'B00004WLM1': 1,
#   'B00002STI2': 3,
#   'B000046Q7R': 3,
#   'B00004UE0G': 8,
#   'B00004W4QJ': 2,
#   'B00001OHC1': 5,
#   'B000021Y5R': 5,
#   'B00002ST6R': 5,
#   'B00002ST6T': 5,
#   'B00002ST6Q': 5,
#   'B00002ST7G': 5,
#   'B00002STJI': 5,
#   'B000038AAN': 5,
#   'B00004SA3U': 5,
#   'B00004U1R4': 5,
#   'B00004U62C': 5,
#   'B00004U8R2': 5,
#   'B00004U62K': 5,
#   'B00004U47Q': 5,
#   'B00000K514': 4,
#   'B00004R9I4': 3,
#   'B00001IVCC': 2,
#   'B00002CF8Q': 2,
#   'B00002ST7U': 2,
#   'B00002ST8W': 2,
#   'B000050569': 2,
#   'B0000507UR': 4,
#   'B00002SX0F': 0,
#   'B00000DMB6': 7,
#   'B00001X50M': 1,
#   'B00004LC81': 0,
#   'B00002R12G': 0,
#   'B000009QCX': 7,
#   'B000006OWT': 3,
#   'B00000JHPT': 3,
#   'B00004R9FI': 3,
#   'B00004R61M': 4,
#   'B000007NJC': 6,
#   'B00003W8C7': 6,
#   'B00004T4XJ': 7,
#   'B00004U4SR': 2,
#   'B00004ZEEH': 2,
#   'B00002S82C': 8,
#   'B00002SUPU': 8,
#   'B00004XRBD': 8,
#   'B00001ZT53': 1,
#   'B00002R29G': 1,
#   'B00004W4R0': 1,
#   'B00004WLQ6': 1,
#   'B00001ZUHJ': 2,
#   'B000038I9H': 2,
#   'B000038AAS': 2,
#   'B000035YBQ': 1,
#   'B00004T783': 8,
#   'B00004W4R7': 1,
#   'B00004ZBO5': 6,
#   'B00004C8S0': 4,
#   'B00004DITL': 8,
#   'B00001NTSN': 8,
#   'B00001OWYQ': 8,
#   'B00004UE0Q': 8,
#   'B0000206H5': 1,
#   'B00004TEQD': 6,
#   'B00004U4QA': 6,
#   'B00004U62B': 6,
#   'B00004YC3U': 4,
#   'B00000K10O': 5,
#   'B00004SR5N': 1,
#   'B00004U4QE': 5,
#   'B00004TJDI': 1,
#   'B00004VUGN': 1,
#   'B00004WKKC': 1,
#   'B00004U62O': 1},
#  np.int64(2001): {'B00004W4WK': 0,
#   'B000056KDV': 1,
#   'B000056WU9': 0,
#   'B00005LOW9': 0,
#   'B00000F1GM': 2,
#   'B00000K125': 3,
#   'B00000K3X9': 3,
#   'B00004TEQD': 3,
#   'B00004UDVL': 3,
#   'B00005Q8LY': 0,
#   'B00004U8KO': 1,
#   'B00004U55G': 1,
#   'B00002STYN': 4,
#   'B00004WHWG': 1,
#   'B00000DMB2': 2,
#   'B00000DMAT': 2,
#   'B00000DMAX': 2,
#   'B00000JQQM': 2,
#   'B00004UG9B': 2,
#   'B000056FLI': 2,
#   'B00005ME7X': 3,
#   'B00005ME7Z': 2,
#   'B00005QDPZ': 0,
#   'B00004THPG': 2,
#   'B00004UDVU': 0,
#   'B00004XRBM': 1,
#   'B00002SU5D': 1,
#   'B00004KHDP': 1,
#   'B000056O4Q': 1,
#   'B00005QEFM': 4,
#   'B00000K2R4': 3,
#   'B00004S99R': 3,
#   'B00004U8H1': 1,
#   'B00004UE0O': 1,
#   'B00004WGW1': 1,
#   'B00004YMZY': 0,
#   'B00004Z0MH': 1,
#   'B000059Z7G': 6,
#   'B00005BJ9G': 4,
#   'B00005MDZY': 4,
#   'B00000DMB3': 2,
#   'B00000I1BY': 3,
#   'B00002STEZ': 2,
#   'B000034DMG': 3,
#   'B000038A7C': 4,
#   'B0000503MO': 0,
#   'B00005BK7X': 0,
#   'B00005J536': 0,
#   'B00000K39I': 3,
#   'B00001QEQA': 1,
#   'B0000296O5': 3,
#   'B00002EPYY': 1,
#   'B00003W8C7': 1,
#   'B00004OCYG': 1,
#   'B00004W4QV': 0,
#   'B00004U1QY': 2,
#   'B00004U1R2': 6,
#   'B00004KHB7': 1,
#   'B00004T72D': 0,
#   'B00004U47F': 0,
#   'B00004U5VN': 0,
#   'B00004Y57G': 3,
#   'B00005NZ1G': 0,
#   'B000056BSY': 0,
#   'B00002R28C': 3,
#   'B00004TC6E': 3,
#   'B00002ST7F': 8,
#   'B00002STXQ': 2,
#   'B000035XKJ': 8,
#   'B00004R9G7': 8,
#   'B00004SW27': 8,
#   'B00004U5VI': 0,
#   'B00004ZDFY': 6,
#   'B00005LIP5': 0,
#   'B00001KUII': 3,
#   'B00002CF9M': 1,
#   'B000038IFX': 3,
#   'B00004S99S': 0,
#   'B000059Z8I': 6,
#   'B00002S6BL': 1,
#   'B00004R61M': 1,
#   'B00004VXAZ': 3,
#   'B00005AG0S': 1,
#   'B00004VP46': 1,
#   'B00005N9AC': 1,
#   'B00004ZBO5': 1,
#   'B00005BIQK': 1,
#   'B00000K2R6': 6,
#   'B00000T94P': 3,
#   'B00004U3CR': 0,
#   'B00004YC3N': 0,
#   'B00005NCAN': 0,
#   'B00005NZ1J': 4,
#   'B00005O0I7': 4,
#   'B00005NZ1I': 4,
#   'B00005OLWV': 0,
#   'B00005Q8LR': 0,
#   'B00005QEFG': 0,
#   'B00005R5PT': 0,
#   'B00005R5PX': 0,
#   'B00005RJJW': 0,
#   'B00004S4YD': 6,
#   'B00005BIGC': 6,
#   'B00005BJ9F': 6,
#   'B00001IVGE': 1,
#   'B00004YC3U': 1,
#   'B00005LZNI': 0,
#   'B000058AJL': 2,
#   'B00002STKN': 0,
#   'B00004Z3BW': 0,
#   'B00005B70X': 0,
#   'B00000IFRI': 2,
#   'B00004TEXU': 0,
#   'B00004U3BX': 3,
#   'B00004W4QS': 6,
#   'B00004ZCP0': 3,
#   'B00004YRVW': 0,
#   'B00005NCA7': 0,
#   'B00005NN5G': 0,
#   'B000059Z7O': 0,
#   'B00005NZ1V': 0,
#   'B00004T783': 1,
#   'B00004WFVZ': 1,
#   'B00005B4AS': 1,
#   'B00005NIMB': 1,
#   'B00000IODY': 3,
#   'B00000JIUG': 3,
#   'B00000K1VE': 3,
#   'B00001XDUB': 3,
#   'B00001X50M': 3,
#   'B00004R9IG': 0,
#   'B00004SR5M': 0,
#   'B00004T4XM': 3,
#   'B00005A775': 3,
#   'B00004U62O': 3,
#   'B00004YRQ9': 3,
#   'B00004YRQA': 6,
#   'B00005AW20': 6,
#   'B00004WKKC': 3,
#   'B00004U4R8': 2,
#   'B00005AW1W': 6,
#   'B00005AW1Y': 0,
#   'B00005NCCI': 0,
#   'B00005QDPT': 0,
#   'B00005R5Q0': 0,
#   'B00005TQG6': 0,
#   'B00005UJS8': 0,
#   'B00005B8FZ': 4,
#   'B00005BJ99': 2,
#   'B00005CFHM': 0,
#   'B00004U5VF': 6,
#   'B00004YUWA': 2,
#   'B00005B70Y': 6,
#   'B00005NZ1K': 2,
#   'B00005JY67': 0,
#   'B00005NH6C': 2,
#   'B000056KDW': 1,
#   'B00000K10U': 3,
#   'B00001ZWUQ': 0,
#   'B0000488VR': 3,
#   'B00004RBQX': 3,
#   'B00005B8GF': 3,
#   'B00000JL60': 1,
#   'B00000K1V9': 3,
#   'B00000K2X5': 3,
#   'B000038ABM': 3,
#   'B00004WLQ6': 3,
#   'B00005NN5L': 0,
#   'B00004KHB3': 1,
#   'B00000DMAN': 1,
#   'B00000JL6V': 1,
#   'B00000K4MC': 4,
#   'B00001NFRB': 1,
#   'B00001XDTK': 1,
#   'B00002NDRY': 1,
#   'B00004S3AI': 1,
#   'B00004S653': 2,
#   'B00004T1MD': 1,
#   'B00004T00A': 1,
#   'B00004T1MG': 1,
#   'B00004TJ2T': 1,
#   'B00004U55E': 1,
#   'B00004XRBD': 1,
#   'B00004ZBSX': 1,
#   'B00005A3I8': 1,
#   'B00005ME4Z': 1,
#   'B00004SV2B': 1,
#   'B00002Z72E': 6,
#   'B000031KJX': 6,
#   'B000059S8D': 6,
#   'B00001ZWMV': 1,
#   'B00004U5VK': 0,
#   'B00005B70K': 0,
#   'B00005ME6O': 3,
#   'B00005ML10': 0,
#   'B00004WLQV': 0,
#   'B000056SNY': 0,
#   'B000055Y1L': 2,
#   'B00002SUOV': 1,
#   'B00005CFHG': 0,
#   'B00005LOXE': 3,
#   'B00004YROX': 0,
#   'B00004U5VV': 0,
#   'B00004UFRI': 0,
#   'B000059Z7U': 0,
#   'B00005ME6N': 0,
#   'B00005O0I2': 0,
#   'B000038ABG': 0,
#   'B00004W4S4': 0,
#   'B00004Y5SQ': 0,
#   'B00004YKHS': 0,
#   'B00004YNVG': 6,
#   'B0000524NB': 0,
#   'B000056H2D': 0,
#   'B00005BIG7': 0,
#   'B00005JY68': 0,
#   'B00005NCA5': 0,
#   'B00005NCCR': 0,
#   'B00005NFN6': 0,
#   'B00005OLWW': 0,
#   'B00005TNI6': 0,
#   'B000038A6U': 4,
#   'B00005AQRH': 6,
#   'B00004T77G': 1,
#   'B00005Q8IO': 4,
#   'B00000JNHJ': 2,
#   'B00004WGVY': 1,
#   'B00002CF8U': 1,
#   'B000046Q7Q': 2,
#   'B00004UE0I': 1,
#   'B00004ZBOD': 1,
#   'B00004ZBQB': 1,
#   'B00004W4VH': 0,
#   'B000059Z8B': 0,
#   'B00004U5VU': 0,
#   'B00000IZ8A': 6,
#   'B00001QED2': 6,
#   'B00004LN2T': 2,
#   'B00004RIPJ': 4,
#   'B00004WHW7': 6,
#   'B00004YB5U': 6,
#   'B00005NGL9': 0,
#   'B00000DMA8': 1,
#   'B00000K115': 6,
#   'B00001P4Y6': 6,
#   'B000056KDY': 6,
#   'B00000K50S': 1,
#   'B00002STL9': 1,
#   'B00004UE0V': 1,
#   'B00005LABK': 1,
#   'B00005QEZ7': 2,
#   'B00005JG30': 0,
#   'B00005O628': 0,
#   'B00004KHDM': 3,
#   'B00001X5CG': 1,
#   'B00004U8KC': 1,
#   'B00004Y54K': 1,
#   'B00004ZC7H': 1,
#   'B0000507UR': 1,
#   'B000059WIM': 1,
#   'B00004U8K5': 1,
#   'B00005ML0X': 0,
#   'B00004UDVJ': 6,
#   'B00005NZ1S': 0,
#   'B00005O626': 0,
#   'B00005O0I3': 4,
#   'B00005Q8M0': 0,
#   'B00005QDPX': 0,
#   'B00005QDQ1': 0,
#   'B00001XDKO': 1,
#   'B0000296ZD': 1,
#   'B00004OCYH': 1,
#   'B00004RFBE': 1,
#   'B00004TJCL': 1,
#   'B00004TSX4': 1,
#   'B00004VP44': 1,
#   'B00004W419': 1,
#   'B000053UJ2': 1,
#   'B000058CCN': 1,
#   'B000059L4Q': 1,
#   'B00005OV6N': 1,
#   'B00005NHDU': 1,
#   'B00002CF96': 1,
#   'B00004TKMB': 0,
#   'B00004U62K': 0,
#   'B000059TCG': 0,
#   'B000059Z7Q': 0,
#   'B00005AYE5': 6,
#   'B00005B70T': 0,
#   'B00005B8G1': 0,
#   'B00005MDZZ': 4,
#   'B00005NN5J': 0,
#   'B00005NYZ7': 0,
#   'B00004KHAG': 3,
#   'B00001ZUL7': 0,
#   'B00005MO5E': 0,
#   'B00000K4BU': 3,
#   'B000035YBQ': 3,
#   'B00004WESW': 3,
#   'B000053VWB': 3,
#   'B00005B8IX': 4,
#   'B00005LABJ': 1,
#   'B00005QJDS': 1,
#   'B00004WFZK': 3,
#   'B00002SV0E': 1,
#   'B00005A3I5': 1,
#   'B00005QIR3': 1,
#   'B00000J2W7': 2,
#   'B00001IVR9': 2,
#   'B00001SHNG': 4,
#   'B00005QIR8': 3,
#   'B0000541Z7': 2,
#   'B000056Q1E': 2,
#   'B00004RBOV': 3,
#   'B00002SU5C': 1,
#   'B00004YLZM': 1,
#   'B00001YVIB': 1,
#   'B00004NS0Z': 1,
#   'B00005R6Z0': 1,
#   'B00005BL00': 4,
#   'B00002EPYJ': 3,
#   'B00004WLMA': 2,
#   'B00000JRSB': 3,
#   'B000021Y2Y': 3,
#   'B00005CFHN': 2,
#   'B00002STHN': 3,
#   'B00004SDGB': 1,
#   'B00004T1M7': 1,
#   'B00004U8GM': 1,
#   'B00005ML8K': 1,
#   'B00005QX48': 1,
#   'B00005QX4F': 1,
#   'B00001SVE2': 1,
#   'B00002STGV': 0,
#   'B00001ZULK': 0,
#   'B00005JC8D': 1,
#   'B00005A9VM': 1,
#   'B000040OEH': 2,
#   'B00001ZUGT': 3,
#   'B00005Q8J1': 3,
#   'B00005RL4E': 0,
#   'B00005LIP8': 0,
#   'B00005MKYZ': 6,
#   'B000051SGS': 1,
#   'B00005QIQP': 0,
#   'B00002STJI': 1,
#   'B00004TBGT': 3,
#   'B00004XOM1': 3,
#   'B00001IVRD': 2,
#   'B00001IVLY': 1,
#   'B00004NHFO': 2,
#   'B000059Z7R': 3,
#   'B00004R9IB': 6,
#   'B00004U1R0': 6,
#   'B00005QJ01': 0,
#   'B00005QSLC': 0,
#   'B00004R8WH': 3,
#   'B00004S99O': 0,
#   'B00000K2GJ': 2,
#   'B00002STHV': 2,
#   'B00000I1BE': 2,
#   'B00000J97G': 6,
#   'B00002STGQ': 6,
#   'B000031KJQ': 6,
#   'B00004TEYR': 6,
#   'B00005BIGE': 6,
#   'B00005NZ1M': 4,
#   'B00001LCDP': 2,
#   'B00001YVBL': 2,
#   'B00004UE0E': 1,
#   'B00005B441': 2,
#   'B000006RGS': 0,
#   'B00002R28F': 2,
#   'B00005NZ1W': 0,
#   'B00005A774': 3,
#   'B00000K2GI': 6,
#   'B00004U1R3': 6,
#   'B00004XOMV': 6,
#   'B00005ME6F': 2,
#   'B00005NOFJ': 2,
#   'B00004U5VS': 6,
#   'B00004W4WH': 0,
#   'B00005ML0Z': 0,
#   'B00000J9J9': 0,
#   'B00000K4C9': 0,
#   'B00001LCDF': 0,
#   'B0000488VP': 0,
#   'B00004UFFP': 0,
#   'B00004XRBB': 0,
#   'B000051WA5': 0,
#   'B000051WA6': 0,
#   'B000059XSD': 0,
#   'B00002970O': 0,
#   'B000051WA3': 0,
#   'B00004T4XK': 0,
#   'B00004TEXF': 3,
#   'B00004U3GL': 0,
#   'B000059O8B': 0,
#   'B00005N7YK': 1,
#   'B00005N7YI': 1,
#   'B00004WKN9': 0,
#   'B00004W4WJ': 0,
#   'B00000IPDS': 0,
#   'B00000INR2': 4,
#   'B00002STGL': 0,
#   'B00003OTI3': 4,
#   'B00002SU5A': 0,
#   'B00004VP4M': 1,
#   'B00005N6ZL': 1,
#   'B0000524PQ': 0,
#   'B00005NHPI': 0,
#   'B00000IXB8': 3,
#   'B00004WGVX': 1,
#   'B00001ZWXF': 3,
#   'B00004RFB9': 3,
#   'B00004TCT3': 2,
#   'B00005KHYO': 0,
#   'B00005NCAG': 0,
#   'B00005NUIW': 0,
#   'B00004T77P': 1,
#   'B000006OVI': 3,
#   'B00004S99N': 3,
#   'B00005NUJ3': 0,
#   'B00004YZAU': 8,
#   'B00005BJ9B': 2,
#   'B00000K10O': 0,
#   'B00004SA3U': 0,
#   'B00004WHWC': 1,
#   'B000058A57': 1,
#   'B00005AC4D': 6,
#   'B000056MK0': 1,
#   'B00005NHAI': 1,
#   'B00001LAE2': 2,
#   'B00000DMAA': 2,
#   'B00004XMRL': 3,
#   'B00002SX0F': 6,
#   'B00004U5IF': 6,
#   'B00005NCAK': 6,
#   'B00005OARM': 4,
#   'B00005RCR2': 6,
#   'B00005QX2X': 1,
#   'B00005A8U0': 1,
#   'B00005Q8LV': 0,
#   'B00005QEFL': 0,
#   'B00004ZBO4': 1,
#   'B00005OWBL': 1,
#   'B00005S8J2': 1,
#   'B00004Y7SZ': 1,
#   'B00004C8SI': 0,
#   'B00004NS01': 0,
#   'B00002SVWG': 3,
#   'B00004U4QE': 6,
#   'B0000520GG': 6,
#   'B00005ME8T': 3,
#   'B00004TTHT': 1,
#   'B00004WGRX': 1,
#   'B00004U1IO': 3,
#   'B00004W4QJ': 3,
#   'B00000K1VA': 3,
#   'B00004S9AD': 2,
#   'B00004U8KL': 1,
#   'B00000I1BX': 9,
#   'B00004YZAO': 9,
#   'B00002SVCV': 9,
#   'B000035XVG': 9,
#   'B0000524NK': 3,
#   'B00004WMVL': 3,
#   'B00001ZT9E': 0,
#   'B00004VWGQ': 0,
#   'B00000DMAQ': 2,
#   'B00000DMAR': 2,
#   'B000034DC2': 2,
#   'B00005NH6B': 0,
#   'B00005ME6L': 0,
#   'B00002STIB': 0,
#   'B00003OPES': 1,
#   'B00004U5VE': 3,
#   'B00001ZUHJ': 3,
#   'B000038AB3': 3,
#   'B00004U4R4': 3,
#   'B00004WLMB': 3,
#   'B00004WLZ7': 3,
#   'B00005N9CQ': 6,
#   'B00005NN8Z': 0,
#   'B00000IWIW': 6,
#   'B00005ATSM': 6,
#   'B00005J8EH': 6,
#   'B00005N7YS': 1,
#   'B00004SWLT': 6,
#   'B00005B70U': 6,
#   'B00004UE0G': 1,
#   'B00005NEAH': 0,
#   'B00005QI67': 0,
#   'B00005AR29': 0,
#   'B0000522AC': 0,
#   'B0000296ZN': 1,
#   'B00005ME68': 1,
#   'B00004U5X1': 1,
#   'B00005RKO7': 0,
#   'B000006OVJ': 1,
#   'B000035Y6V': 1,
#   'B000059S78': 1,
#   'B00004R9I4': 4,
#   'B00005LOY9': 6,
#   'B00005QEFK': 6,
#   'B000050FB3': 6,
#   'B00005LLSS': 0,
#   'B00005R1IZ': 2,
#   'B00005KAY0': 4,
#   'B000056PJG': 4,
#   'B00004ZBOE': 1,
#   'B00005QB9N': 1,
#   'B00002STNR': 1,
#   'B00004U1P5': 1,
#   'B00004TJDI': 3,
#   'B00004TTTQ': 3,
#   'B000056OYN': 1,
#   'B00000K3XB': 3,
#   'B00001QEQL': 0,
#   'B00005EBF8': 1,
#   'B00005NUIZ': 0,
#   'B000056KDZ': 1,
#   'B00004SWL9': 0,
#   'B00004XOM2': 3,
#   'B00005RL3Y': 3,
#   'B00004XOLO': 3,
#   'B00004WMRF': 3,
#   'B000056PGW': 3,
#   'B00005MNRW': 3,
#   'B00004T70W': 4,
#   'B00005B8G0': 4,
#   'B00005Q8M4': 4,
#   'B000035Y09': 3,
#   'B00004SVBP': 3,
#   'B000058513': 3,
#   'B000059Z7H': 6,
#   'B00005BISG': 3,
#   'B00005LIPF': 8,
#   'B00002CF8Q': 1,
#   'B00004UE0K': 2,
#   'B00005N7YJ': 1,
#   'B00005OLWB': 0,
#   'B00002STH0': 2,
#   'B00004SVXW': 4,
#   'B00004SVS3': 6,
#   'B00004W4WI': 0,
#   'B00002EQAP': 2,
#   'B00005N9AD': 1,
#   'B00005NFN5': 0,
#   'B000023VUP': 3,
#   'B00004U62A': 3,
#   'B00004R8V4': 3,
#   'B00005CFH5': 3,
#   'B00005NGR0': 1,
#   'B00005ULW9': 1,
#   'B00002STXN': 3,
#   'B00005ATSN': 6,
#   'B00002STF7': 0,
#   'B00005R5PZ': 0,
#   'B00005K89C': 1,
#   'B00005NFN4': 0,
#   'B00000K4LL': 1,
#   'B00004S9AF': 3,
#   'B00004U5VP': 0,
#   'B00004U62Q': 0,
#   'B00004T77J': 2,
#   'B00005NHAE': 1,
#   'B000059XOB': 1,
#   'B000050ZEN': 0,
#   'B00005RD6X': 1,
#   'B00000I1BB': 6,
#   'B00001OHC1': 6,
#   'B00001ZWP8': 2,
#   'B00004S9A0': 6,
#   'B00000K514': 1,
#   'B00002SV6G': 1,
#   'B00001QER9': 3,
#   'B0000520GE': 0,
#   'B00002SVFX': 4,
#   'B00004UFRD': 0,
#   'B00005LBHM': 6,
#   'B00005RCPR': 3,
#   'B00000IG7T': 3,
#   'B00000J9JI': 3,
#   'B00002SV61': 3,
#   'B000035XMK': 3,
#   'B000035Y08': 3,
#   'B000035XMM': 3,
#   'B000035Y2Q': 3,
#   'B000035Y63': 3,
#   'B000035Y6N': 3,
#   'B00004SVR9': 3,
#   'B00004TMFD': 3,
#   'B00004W4S3': 3,
#   'B00004SVR4': 3,
#   'B00004VXAV': 1,
#   'B00002S6CC': 1,
#   'B00004WI4D': 1,
#   'B00004LN2R': 3,
#   'B000038AAN': 3,
#   'B00001QEQ9': 1,
#   'B00005KAAZ': 1,
#   'B00000IZ7Q': 1,
#   'B00004TSX8': 1,
#   'B00004U55D': 1,
#   'B00000I1BK': 3,
#   'B00002R28Q': 3,
#   'B00000I1BO': 3,
#   'B00000I1BF': 2,
#   'B00004SWLZ': 2,
#   'B00004ZASP': 1,
#   'B00004WHWF': 1,
#   'B00005QWWD': 1,
#   'B00004VWGP': 0,
#   'B00005RCQY': 0,
#   'B000050HEK': 0,
#   'B000034DE9': 0,
#   'B000059Z7F': 0,
#   'B00005NN7I': 0,
#   'B00005KAPT': 6,
#   'B00004R8XR': 0,
#   'B00004R9IK': 0,
#   'B00004YKI6': 0,
#   'B00005Q5CG': 0,
#   'B00005Q8IR': 0,
#   'B00002STX4': 4,
#   'B00002SVG2': 3,
#   'B00002SX0E': 2,
#   'B000056WXG': 6,
#   'B00002EPZ2': 1,
#   'B00005NBFN': 0,
#   'B00000K4D4': 2,
#   'B00002SVBZ': 2,
#   'B00004WI4M': 2,
#   'B00005BH3T': 2,
#   'B00004SPRD': 3,
#   'B000006OVE': 3,
#   'B00004U3GC': 6,
#   'B00004KHB0': 1,
#   'B00002SU53': 1,
#   'B00004TH9E': 1,
#   'B00005OLWT': 4,
#   'B000059S79': 4,
#   'B00005BZE0': 0,
#   'B000056PJE': 1,
#   'B00005Q6Y7': 0,
#   'B00005R6YZ': 0,
#   'B00005S0OV': 0,
#   'B00000K4CC': 0,
#   'B00004W4S2': 3,
#   'B00000K2R5': 0,
#   'B00004YRSH': 6,
#   'B00004RBOK': 6,
#   'B000023MCN': 3,
#   'B000059H0X': 2,
#   'B00005ME6A': 3,
#   'B00004WYR7': 3,
#   'B00000K4AX': 1,
#   'B00004DITL': 1,
#   'B00005AG1H': 1,
#   'B00000K2XJ': 1,
#   'B00001NFS5': 1,
#   'B00005J53A': 2,
#   'B00005JYBA': 4,
#   'B00005BJ9E': 2,
#   'B00005QIQM': 1,
#   'B00004DSDE': 1,
#   'B00005J99G': 3,
#   'B00005NCB6': 0,
#   'B00005R5PO': 0,
#   'B00004Y7SY': 1,
#   'B00005ME6E': 4,
#   'B00005NCD0': 0,
#   'B00005NN7J': 4,
#   'B00000I1BQ': 2,
#   'B00004U4R9': 2,
#   'B00005ASGK': 1,
#   'B00005O0I9': 4,
#   'B00000DMB9': 4,
#   'B00000F1GS': 4,
#   'B00000I1B8': 4,
#   'B00000J2OO': 4,
#   'B00000JHPD': 4,
#   'B00000K4E1': 4,
#   'B000021Y30': 4,
#   'B00002970G': 4,
#   'B00002R29G': 4,
#   'B00002ST2A': 4,
#   'B00002STFP': 4,
#   'B00002STGN': 4,
#   'B00002STH5': 4,
#   'B00002STFN': 4,
#   'B00002STYS': 4,
#   'B00002STZH': 4,
#   'B00002SU3D': 4,
#   'B00002SV58': 4,
#   'B00002SVFR': 4,
#   'B00002STX6': 4,
#   'B00002SU0O': 4,
#   'B00002SW4D': 4,
#   'B00002SW4F': 4,
#   'B000031KJM': 4,
#   'B000035XZD': 4,
#   'B000035XYL': 4,
#   'B000035XYA': 4,
#   'B000035Y24': 4,
#   'B000035Y3N': 4,
#   'B000035Y13': 4,
#   'B000035Y0L': 4,
#   'B000035Y0J': 4,
#   'B000035Y4Y': 4,
#   'B000035Y6D': 4,
#   'B000035Y3I': 4,
#   'B00004S9A2': 4,
#   'B00004S9AA': 4,
#   'B00004SVP1': 4,
#   'B00004SVVH': 4,
#   'B00004SVO2': 4,
#   'B00004SVP2': 4,
#   'B00004SVUW': 4,
#   'B00004SVYE': 4,
#   'B00004SVYT': 4,
#   'B00004SVTL': 4,
#   'B00004SVVJ': 4,
#   'B00004SVYR': 4,
#   'B00004TEXR': 4,
#   'B00004TMBO': 4,
#   'B000052WM0': 4,
#   'B00005AV8W': 4,
#   'B00005AV86': 4,
#   'B00005NNGC': 4,
#   'B00005OBQB': 4,
#   'B00005OMZV': 4,
#   'B000MX592O': 4,
#   'B00002ST29': 4,
#   'B000035XGG': 4,
#   'B000035XZW': 4,
#   'B00005C7NY': 4,
#   'B00002CF98': 1,
#   'B00002CF5W': 1,
#   'B00002SFNG': 1,
#   'B00002K13U': 6,
#   'B00003OPEQ': 1,
#   'B00004NS11': 1,
#   'B00005NN5A': 3,
#   'B00001NFUA': 2,
#   'B00001OWYW': 3,
#   'B00002STFD': 2,
#   'B00005NCCW': 2,
#   'B00002SV55': 0,
#   'B00005QDPU': 0,
#   'B00005R5PU': 0,
#   'B00005RCR0': 0,
#   'B00002SU2P': 0,
#   'B00002STGM': 2,
#   'B00005MEMR': 1,
#   'B00000JQQH': 3,
#   'B00000K5D8': 3,
#   'B00005043W': 3,
#   'B000056PJF': 2,
#   'B0008IST98': 1,
#   'B00002AH2T': 4,
#   'B00002STPF': 3,
#   'B0000296ZB': 1,
#   'B00002SA3S': 1,
#   'B00002SVML': 1,
#   'B00004R9AL': 1,
#   'B00004SUK6': 1,
#   'B00004UE0U': 1,
#   'B00004VP4B': 1,
#   'B00004WI4E': 1,
#   'B000056PJI': 1,
#   'B00005B444': 1,
#   'B00000IKQH': 2,
#   'B00001IVCC': 2,
#   'B000047GEI': 2,
#   'B00004SVUF': 3,
#   'B00004SVQL': 3,
#   'B00004SVQP': 3,
#   'B00001W0J6': 2,
#   'B00005NEAG': 3,
#   'B00001ZWPX': 3,
#   'B00004WKHO': 3,
#   'B00005LOYC': 3,
#   'B0000524NH': 3,
#   'B0000524NF': 0,
#   'B00001IVB4': 1,
#   'B00002CF94': 1,
#   'B00002CF9G': 1,
#   'B00004TFLJ': 1,
#   'B00001XDKL': 3,
#   'B00002EPY1': 1,
#   'B00005O0I5': 4,
#   'B000059Z7Y': 0,
#   'B00001ZWNA': 0,
#   'B00004WGNL': 0,
#   'B00005A9W0': 1,
#   'B0000524PF': 0,
#   'B00004DITJ': 1,
#   'B00004VUFH': 1,
#   'B00005AG1J': 1,
#   'B00002ST6T': 8,
#   'B00002ST75': 8,
#   'B00002ST7H': 8,
#   'B00002ST6O': 8,
#   'B00002ST7G': 8,
#   'B00002ST79': 8,
#   'B00002ST8W': 8,
#   'B00002SVNY': 8,
#   'B00002SVOB': 8,
#   'B00002SVPA': 8,
#   'B00002SWA1': 8,
#   'B000035XJD': 8,
#   'B000035XKY': 8,
#   'B000035XK9': 8,
#   'B000035XI6': 8,
#   'B000035XLQ': 8,
#   'B000035XR9': 8,
#   'B000035XKN': 8,
#   'B000035XLF': 8,
#   'B000035XKX': 8,
#   'B000035XJA': 8,
#   'B00002ST6N': 8,
#   'B000035XJH': 8,
#   'B000035XJJ': 8,
#   'B000035XLM': 8,
#   'B000035XKM': 8,
#   'B000056Q0P': 1,
#   'B00004YUBX': 0,
#   'B00005RCQ5': 0,
#   'B00004SWM0': 3,
#   'B00002SVEM': 2,
#   'B00002ST3U': 2,
#   'B00001OX4T': 2,
#   'B00005NUIR': 0,
#   'B0000296NT': 3,
#   'B00004Y7ZO': 6,
#   'B000035XMQ': 3,
#   'B00005N7YQ': 1,
#   'B00004U5VJ': 0,
#   'B00005LOW5': 6,
#   'B00005MOMJ': 2,
#   'B000035YBP': 0,
#   'B00004VU67': 2,
#   'B00004SPY0': 2,
#   'B00005O62D': 4,
#   'B00005NZ1T': 1,
#   'B00004RBON': 2,
#   'B00004SPRC': 3,
#   'B00005B70Q': 3,
#   'B00004VWGR': 0,
#   'B00001QHXE': 6,
#   'B00002ST27': 6,
#   'B000035XB0': 6,
#   'B000058BCU': 6,
#   'B00005OLX5': 3,
#   'B00000DMB6': 2,
#   'B00000I1C0': 2,
#   'B00000I1C1': 2,
#   'B000034DC6': 2,
#   'B000034DCF': 2,
#   'B00005R5PN': 2,
#   'B000021Y1K': 2,
#   'B00000K2YD': 1,
#   'B00004NHFD': 1,
#   'B00002EPYE': 3,
#   'B00002SVWA': 0,
#   'B000006OVG': 2,
#   'B00002DHEV': 3,
#   'B00002SVX5': 3,
#   'B000038I9H': 3,
#   'B00004S9AC': 3,
#   'B00002EIZS': 2,
#   'B00003OPCY': 2,
#   'B00002R28I': 0,
#   'B000034DC7': 3,
#   'B00005NGLC': 0,
#   'B00005NGLA': 0,
#   'B00002SV0U': 3,
#   'B000059Z7S': 3,
#   'B00005NZ1Q': 4,
#   'B00005NZ1X': 0,
#   'B00002STKO': 3,
#   'B00005NCA6': 0,
#   'B00004T4XI': 3,
#   'B000006P0K': 3,
#   'B00004W4VG': 0,
#   'B00004YMZS': 0,
#   'B00000IKCC': 3,
#   'B00002STPM': 3,
#   'B00002NDSI': 1,
#   'B000059Z7T': 0,
#   'B00004R9FE': 3,
#   'B00004TNDY': 0,
#   'B000046S41': 4,
#   'B00001R3XK': 1,
#   'B00004RGJE': 1,
#   'B00004U4QI': 6,
#   'B00005BJ9C': 6,
#   'B00004U359': 6,
#   'B00000I1BR': 2,
#   'B00000J96V': 2,
#   'B00002STPX': 2,
#   'B00002STPL': 2,
#   'B00000DMAO': 2,
#   'B00004TJ2N': 1,
#   'B00004R9FI': 3,
#   'B00004S99M': 3,
#   'B00002SW3O': 6,
#   'B00004SVP8': 6,
#   'B00004SVTN': 6,
#   'B00004SVPT': 6,
#   'B00004S99X': 3,
#   'B00004SR5N': 3,
#   'B00005MO5G': 2,
#   'B00002970H': 2,
#   'B00004SW23': 0,
#   'B00004T4XO': 3,
#   'B00002SUDC': 1,
#   'B00004YKX4': 1,
#   'B00001XDK9': 1,
#   'B00001P4QN': 0,
#   'B00004ZB7E': 1,
#   'B00005O62A': 0,
#   'B00005RCNC': 0,
#   'B00005N9A7': 6,
#   'B00000IKCG': 2,
#   'B00005Q5CW': 0,
#   'B00005R5PV': 0,
#   'B00005QWUG': 4,
#   'B00000K11D': 0,
#   'B00002971O': 0,
#   'B000034DBS': 3,
#   'B00004VWGS': 0,
#   'B00005C7QT': 5,
#   'B00005RCQR': 5,
#   'B00004U1QX': 6,
#   'B00004U1R8': 6,
#   'B00000K4EC': 1,
#   'B00002SV4N': 3,
#   'B00002EPYI': 3,
#   'B00002SV5B': 0,
#   'B00001ZULE': 2,
#   'B0000568U1': 6,
#   'B00005T7ZN': 3,
#   'B000006OWT': 2,
#   'B00000F1GO': 2,
#   'B000034DEA': 2,
#   'B00004RC1Y': 3,
#   'B0000296ZP': 1,
#   'B00004UE0Q': 1,
#   'B00005NCAM': 1,
#   'B00000K4C7': 3,
#   'B00000PLUW': 3,
#   'B00002STJH': 3,
#   'B000034DLH': 3,
#   'B00004WMVK': 6,
#   'B000059Z7X': 3,
#   'B00005B2CV': 3,
#   'B00005B2CW': 3,
#   'B00005ME7U': 3,
#   'B00005QZT6': 3,
#   'B00001QERY': 6,
#   'B00004TJE5': 6,
#   'B000021Y2Z': 7,
#   'B00004W4S1': 7,
#   'B00000G16I': 0,
#   'B00000I1BA': 2,
#   'B00004YRQD': 0,
#   'B000056WHK': 0,
#   'B00001XDKF': 2,
#   'B00004YMZV': 0,
#   'B00005A7FK': 1,
#   'B00005K1Z3': 1,
#   'B00005NGS3': 1,
#   'B00002SVFZ': 2,
#   'B000006P0J': 8,
#   'B000035Y7H': 8,
#   'B00005R2GW': 0,
#   'B00005LIOL': 1,
#   'B000056VJU': 1,
#   'B00004XONL': 3,
#   'B000050FAE': 3,
#   'B000056Q1A': 3,
#   'B00002STL2': 3,
#   'B00004Z0FJ': 1,
#   'B00005AG0X': 1,
#   'B00000K117': 3,
#   'B00002STGI': 3,
#   'B00004TTID': 3,
#   'B00004W4VE': 2,
#   'B00005ME6D': 2,
#   'B00002CF8V': 1,
#   'B00005O1GO': 1,
#   'B00005B9CB': 1,
#   'B00000I1BJ': 3,
#   'B00005QWWF': 2,
#   'B00004WMQB': 3,
#   'B00004U627': 0,
#   'B00005NEAI': 3,
#   ...},
#  np.int64(2002): {'B00005NZ1M': 0,
#   'B00005NZ1Q': 0,
#   'B00005O0I5': 1,
#   'B00005NZ1G': 0,
#   'B00005Q5CW': 0,
#   'B00005V6BB': 2,
#   'B000068NM6': 2,
#   'B0000696CZ': 2,
#   'B00005QDPZ': 3,
#   'B00005QSLC': 4,
#   'B00005U8TI': 3,
#   'B00005V3EX': 3,
#   'B00005YVTY': 3,
#   'B0000631WE': 3,
#   'B0000657SP': 3,
#   'B00004TJCL': 5,
#   'B00004YRQA': 2,
#   'B0000503MO': 2,
#   'B00005V3TH': 5,
#   'B00005V9Q1': 5,
#   'B000069D39': 2,
#   'B00006IJJK': 3,
#   'B00001QEQA': 5,
#   'B00002EPYJ': 5,
#   'B00004UE0V': 5,
#   'B00005QX4B': 5,
#   'B00005YTYC': 5,
#   'B000068XKQ': 5,
#   'B00004RFBE': 6,
#   'B00005N7YR': 5,
#   'B00005YTYJ': 5,
#   'B00005T7ZN': 2,
#   'B00005TNI6': 2,
#   'B00005Y1BG': 2,
#   'B00006IJJD': 0,
#   'B00006ISBU': 0,
#   'B00005J536': 1,
#   'B0000664JF': 2,
#   'B0000690ZP': 1,
#   'B0000690ZE': 2,
#   'B00006GSNX': 2,
#   'B00006JZC5': 3,
#   'B00006Z7I3': 2,
#   'B00007LV7Y': 2,
#   'B00002SU5C': 5,
#   'B00004T77A': 3,
#   'B00004Y7SZ': 3,
#   'B000056Q0P': 3,
#   'B00005Q8IO': 1,
#   'B00005Q8LR': 3,
#   'B00005Q8M0': 3,
#   'B00005QJ01': 3,
#   'B00005UK88': 6,
#   'B00005ULXN': 3,
#   'B00005V6B4': 3,
#   'B00005YYFE': 3,
#   'B000066JRN': 3,
#   'B000069LH9': 3,
#   'B00005AW1W': 1,
#   'B00005O1GO': 5,
#   'B00006FWTX': 3,
#   'B000038ABK': 5,
#   'B00004YC3U': 5,
#   'B00004ZBO5': 5,
#   'B00005N9AD': 5,
#   'B000065SQJ': 5,
#   'B00006FXB4': 5,
#   'B0000648A1': 5,
#   'B00002SUOV': 5,
#   'B000056O4Q': 5,
#   'B00005NZ1J': 0,
#   'B00005O0I3': 0,
#   'B00005V5N3': 0,
#   'B00005YDNZ': 0,
#   'B00005NZ1X': 0,
#   'B00005NZ1S': 0,
#   'B00005NZ1K': 0,
#   'B00005QB9O': 0,
#   'B00005QB9M': 5,
#   'B00005V95P': 0,
#   'B0000690ZV': 0,
#   'B00004S9AF': 2,
#   'B00004ZDFY': 2,
#   'B00006CRVB': 5,
#   'B00000DMB3': 3,
#   'B00005R5PO': 2,
#   'B00005UNWB': 2,
#   'B000067DPL': 2,
#   'B00005V6BA': 2,
#   'B00006F2ZP': 2,
#   'B00000F1GM': 4,
#   'B00001OWYW': 2,
#   'B00002ST2A': 4,
#   'B00002STF6': 4,
#   'B00002ST6Q': 4,
#   'B00002SVFV': 2,
#   'B00002SUCW': 4,
#   'B00002SWCO': 4,
#   'B000035XJB': 4,
#   'B000035XYT': 4,
#   'B000035Y3N': 7,
#   'B000035Y17': 4,
#   'B00004RBQX': 4,
#   'B00004SVP1': 4,
#   'B00004SVYH': 4,
#   'B00004SVYF': 7,
#   'B00004TMC3': 4,
#   'B00005AV8O': 7,
#   'B00005MKZ3': 4,
#   'B0000664J6': 3,
#   'B00006B0NR': 0,
#   'B000035XZW': 4,
#   'B00004SVMZ': 4,
#   'B00004YUTK': 4,
#   'B00005Q8LY': 3,
#   'B00000JRSB': 1,
#   'B0000296O5': 3,
#   'B00004U3BX': 2,
#   'B00004Y57G': 2,
#   'B00005EBF8': 5,
#   'B00005QB9N': 0,
#   'B00000JLPC': 2,
#   'B00001ZWP8': 2,
#   'B00002STFH': 2,
#   'B00002STXN': 7,
#   'B00004U1R3': 2,
#   'B00005MO5E': 2,
#   'B00005NBFN': 7,
#   'B00005O0I2': 2,
#   'B00005V95R': 7,
#   'B00005O0I9': 0,
#   'B00005NZ1I': 0,
#   'B00002SVWG': 2,
#   'B00005A3I5': 5,
#   'B000063SAU': 5,
#   'B000066JRH': 3,
#   'B00005NEAI': 7,
#   'B00005UVLM': 0,
#   'B00006IKBD': 0,
#   'B00002SVOE': 8,
#   'B00004SVYW': 8,
#   'B00004SWM0': 8,
#   'B000035XZ0': 8,
#   'B00005NN5G': 7,
#   'B00000JL6V': 5,
#   'B0000507UR': 5,
#   'B00005K1Z3': 5,
#   'B00005YTYB': 5,
#   'B00004SV2B': 5,
#   'B00005V9DX': 5,
#   'B000066TSF': 0,
#   'B00005NZ1R': 0,
#   'B00005V6BG': 0,
#   'B00005V9O3': 0,
#   'B00006JC48': 0,
#   'B00000DMAT': 7,
#   'B00000I1BB': 7,
#   'B00000J9JI': 7,
#   'B00000K1V9': 7,
#   'B00000K2GB': 7,
#   'B00001QER3': 7,
#   'B00001X5BU': 7,
#   'B000021Y1B': 7,
#   'B00002R29G': 7,
#   'B00002STHO': 7,
#   'B00002STYS': 7,
#   'B00002STYR': 7,
#   'B00002SVOJ': 7,
#   'B00002SVFZ': 7,
#   'B00002SW2O': 7,
#   'B00002SU0O': 7,
#   'B00002SW4D': 7,
#   'B00002SWA2': 7,
#   'B00002SW8P': 7,
#   'B000035Y3E': 7,
#   'B000035Y13': 7,
#   'B000035Y4T': 7,
#   'B000035Y38': 7,
#   'B00003OTI3': 7,
#   'B00004R9I2': 7,
#   'B00004SVV7': 7,
#   'B00004SVMY': 7,
#   'B00004SVV8': 7,
#   'B00004SVXV': 7,
#   'B00004SVVT': 7,
#   'B00004SVSS': 7,
#   'B00004SVV9': 7,
#   'B00004SVS3': 7,
#   'B00004U5VI': 7,
#   'B00004U5VE': 7,
#   'B00004U5VF': 7,
#   'B00004WLMA': 7,
#   'B00004YRVW': 7,
#   'B000050FBJ': 7,
#   'B000056SNY': 7,
#   'B000058BCU': 7,
#   'B00005AV8W': 7,
#   'B00005AV86': 7,
#   'B00005B70Y': 7,
#   'B00005C7TU': 7,
#   'B00005LIOL': 7,
#   'B00005NCCI': 7,
#   'B00005NN5A': 7,
#   'B00005Q8J1': 7,
#   'B00005V6BE': 7,
#   'B00006IJJF': 7,
#   'B00006LEM1': 7,
#   'B00000IH04': 7,
#   'B00002STKW': 7,
#   'B00002STYN': 7,
#   'B00002SW4F': 7,
#   'B00002SW2M': 7,
#   'B00005NFN4': 7,
#   'B000059L4L': 5,
#   'B00005O628': 0,
#   'B00005RCQJ': 0,
#   'B000060NPZ': 3,
#   'B00005MDZZ': 2,
#   'B00005OARM': 2,
#   'B00005BR6H': 2,
#   'B0000631WO': 2,
#   'B000066TS6': 2,
#   'B00006IJDC': 2,
#   'B00007B9N4': 4,
#   'B00004WLZ7': 2,
#   'B00005B70K': 2,
#   'B00005BIG7': 2,
#   'B00005LABJ': 5,
#   'B00005LLSS': 2,
#   'B00005V3FB': 3,
#   'B00004S99R': 1,
#   'B0000664JH': 0,
#   'B00006F2ZQ': 0,
#   'B0000690ZT': 3,
#   'B00006FWTZ': 3,
#   'B00006GEX2': 5,
#   'B00005NZ1V': 0,
#   'B00005O0I7': 0,
#   'B00005O0I8': 0,
#   'B00005RCQ5': 0,
#   'B000062YIN': 0,
#   'B0000640A9': 0,
#   'B00006LU9J': 0,
#   'B00007F8PB': 0,
#   'B0000631VI': 0,
#   'B00000K4EC': 4,
#   'B00001ZWMV': 4,
#   'B000038ABS': 2,
#   'B00005O1GM': 5,
#   'B00004ZEEH': 0,
#   'B00005NGLC': 0,
#   'B00005RKO7': 0,
#   'B00006JBS7': 0,
#   'B00005UNWC': 2,
#   'B00005NGR0': 2,
#   'B00005V9NP': 2,
#   'B00005V9O2': 2,
#   'B00005B8FZ': 6,
#   'B00005MDZY': 1,
#   'B00005ML10': 2,
#   'B00005MO5G': 1,
#   'B00005QDQ1': 3,
#   'B00005V9NJ': 2,
#   'B00005YVU2': 3,
#   'B00006418I': 3,
#   'B00006599P': 3,
#   'B00006599R': 0,
#   'B000069BB0': 3,
#   'B00006IKB7': 3,
#   'B00007E1OC': 3,
#   'B00004VP44': 5,
#   'B00004WFVZ': 5,
#   'B00005N9AC': 2,
#   'B00005NIMB': 5,
#   'B00004RGJE': 5,
#   'B00000K117': 1,
#   'B00000K2R4': 1,
#   'B00004R9IC': 0,
#   'B00004SWL9': 10,
#   'B00004XOM2': 0,
#   'B00004TNDY': 2,
#   'B00005NH6B': 2,
#   'B0000690Z9': 2,
#   'B00006AMZR': 2,
#   'B00000K4MC': 5,
#   'B00004U55E': 5,
#   'B00004U8K2': 5,
#   'B00006599Y': 5,
#   'B000065DGB': 5,
#   'B0000663TT': 5,
#   'B000067DPN': 6,
#   'B00006IJMT': 5,
#   'B00006LELU': 5,
#   'B00002CF5W': 5,
#   'B000065EUJ': 5,
#   'B000067FDY': 3,
#   'B000023MCN': 0,
#   'B000059Z7H': 11,
#   'B00006C28Y': 0,
#   'B00006JZQZ': 0,
#   'B00002EPZ2': 5,
#   'B000059L4Q': 5,
#   'B00004TSXC': 5,
#   'B00001IVRD': 5,
#   'B00001IVLY': 5,
#   'B00004ZBOE': 5,
#   'B000056KDY': 5,
#   'B00005BIQK': 5,
#   'B00005KBRD': 5,
#   'B00005N7YM': 5,
#   'B00005N7YK': 5,
#   'B000063UZ1': 5,
#   'B000067O0Q': 5,
#   'B00006F7RJ': 5,
#   'B000059WIM': 5,
#   'B000066RKC': 0,
#   'B000066TS5': 2,
#   'B00006LELA': 5,
#   'B00005YEJD': 2,
#   'B00000I1BY': 2,
#   'B00000I1BJ': 3,
#   'B00000K1VA': 4,
#   'B00001XDUB': 3,
#   'B00001X50M': 3,
#   'B000034DMG': 3,
#   'B000038ABO': 3,
#   'B00005BJ9G': 1,
#   'B00005ME6N': 1,
#   'B00005OWBL': 0,
#   'B00005Q8M4': 3,
#   'B00005RCR0': 3,
#   'B00005YVTW': 2,
#   'B000060NQ1': 4,
#   'B000063CDK': 3,
#   'B00006409Z': 0,
#   'B0000664JE': 0,
#   'B00006F2ZR': 2,
#   'B00006FDLP': 0,
#   'B00006LELI': 3,
#   'B00006M3R6': 4,
#   'B00007DWBL': 3,
#   'B00005Q5CX': 0,
#   'B00005U8TR': 0,
#   'B00005V5LO': 0,
#   'B00005Y404': 0,
#   'B00005YVTX': 0,
#   'B00006599Q': 0,
#   'B000066RK7': 0,
#   'B000069BCI': 0,
#   'B00006LELH': 5,
#   'B00006ZCCD': 0,
#   'B00005RCNC': 0,
#   'B000067K2D': 3,
#   'B00006HBTW': 3,
#   'B00005B70T': 2,
#   'B00005NFN6': 0,
#   'B00005JY68': 0,
#   'B00005Q6Y7': 0,
#   'B00005V5MZ': 0,
#   'B00000K1VK': 2,
#   'B00004UE0U': 2,
#   'B00005KHYO': 2,
#   'B00005O62A': 0,
#   'B00004YUWA': 2,
#   'B00005Q8IR': 2,
#   'B00005RD71': 5,
#   'B0000631VE': 3,
#   'B000067DPD': 0,
#   'B00006LU9L': 0,
#   'B00001OWYQ': 5,
#   'B00005QIQM': 5,
#   'B00005V6C0': 3,
#   'B0000631VG': 3,
#   'B00000K125': 1,
#   'B00005JC8D': 5,
#   'B000056H2D': 1,
#   'B00005UOS7': 3,
#   'B00002R28C': 2,
#   'B00004SVNS': 2,
#   'B00004SVYE': 2,
#   'B00004SVXW': 3,
#   'B00005ML8K': 5,
#   'B00006DY3F': 0,
#   'B00006IZKO': 5,
#   'B00006JZDZ': 0,
#   'B00006LEMX': 2,
#   'B000066TS3': 2,
#   'B00005ME6O': 2,
#   'B00005U8TQ': 0,
#   'B00005QWWF': 0,
#   'B000051QDD': 5,
#   'B00000DMAX': 1,
#   'B00000J2W7': 1,
#   'B000031KJM': 1,
#   'B00004TEXU': 4,
#   'B00005NUJ3': 2,
#   'B00005V6B9': 2,
#   'B00006JC46': 2,
#   'B00005NFN5': 6,
#   'B00005N6ZL': 5,
#   'B00005V3FC': 0,
#   'B00000JIUG': 2,
#   'B00006GSNZ': 1,
#   'B000069BCR': 2,
#   'B00005A774': 3,
#   'B00005BK7X': 2,
#   'B0000631W1': 3,
#   'B00006F2ZS': 3,
#   'B00004TJ2T': 5,
#   'B00001ZUHJ': 2,
#   'B00004YRQ9': 2,
#   'B00005NCCR': 2,
#   'B00005NCA7': 2,
#   'B00005QEFD': 3,
#   'B00005ULXM': 0,
#   'B00005V5N0': 2,
#   'B00005V97I': 5,
#   'B00004Y54K': 5,
#   'B000066TS2': 2,
#   'B00005Q8JJ': 4,
#   'B00006JN5O': 3,
#   'B0000690XO': 0,
#   'B00000K10U': 0,
#   'B00004KHB3': 0,
#   'B00005NZ1W': 0,
#   'B00006IJIS': 0,
#   'B00006IKCE': 0,
#   'B00000K2R7': 0,
#   'B000058A57': 0,
#   'B00005RDYT': 0,
#   'B000069BCN': 0,
#   'B00002STFO': 0,
#   'B00005C4HL': 0,
#   'B00005R5PV': 0,
#   'B00005ME6L': 2,
#   'B00005NJZJ': 2,
#   'B00002STGL': 1,
#   'B00004T1M7': 5,
#   'B000059GTL': 4,
#   'B00005Q8JN': 0,
#   'B00005Y4JF': 0,
#   'B0000631WA': 0,
#   'B00004R9FI': 1,
#   'B00005LIPF': 1,
#   'B0000524NH': 10,
#   'B00005YXC6': 5,
#   'B0000639W2': 5,
#   'B00006IJMU': 0,
#   'B0000524PF': 3,
#   'B00006409Q': 6,
#   'B00006ISBW': 6,
#   'B00007B9MY': 1,
#   'B00005B8G1': 1,
#   'B00000JWGO': 5,
#   'B00005NOFM': 3,
#   'B00005V9NZ': 1,
#   'B0000640A1': 2,
#   'B000065SQ9': 3,
#   'B00004U358': 1,
#   'B00005KAPT': 1,
#   'B000059P75': 5,
#   'B00005LABK': 5,
#   'B00006IJJE': 2,
#   'B0000524NB': 2,
#   'B00006F7S5': 3,
#   'B00006HCHF': 5,
#   'B000056KDW': 5,
#   'B000067O1K': 5,
#   'B00000DMAQ': 0,
#   'B00004VP4M': 5,
#   'B00005J53A': 3,
#   'B00005NHPI': 2,
#   'B00005YWFW': 5,
#   'B00000K2X5': 4,
#   'B00005R1IZ': 2,
#   'B000034DMP': 3,
#   'B000038A77': 3,
#   'B00004U62C': 7,
#   'B00005RCQ1': 3,
#   'B00004Y5YF': 3,
#   'B00005B8IX': 3,
#   'B00005BZE0': 3,
#   'B00005BJ9F': 3,
#   'B00005BJ9E': 3,
#   'B00005BL00': 2,
#   'B00005RL3Y': 3,
#   'B00001QECO': 3,
#   'B00002STJ6': 3,
#   'B00005O629': 0,
#   'B00005NCB6': 5,
#   'B00000J9J9': 7,
#   'B00000PLUW': 3,
#   'B00002NDRY': 5,
#   'B00002STXG': 1,
#   'B00002SVG2': 3,
#   'B00002STGV': 3,
#   'B000035Y1I': 3,
#   'B00004SVYQ': 3,
#   'B00005ME7X': 4,
#   'B000069675': 3,
#   'B00001OPJD': 3,
#   'B00004WI4E': 11,
#   'B00005V6B6': 3,
#   'B00006N5T1': 1,
#   'B00005NCB5': 5,
#   'B00005QX48': 5,
#   'B00006409I': 1,
#   'B00004U4R8': 7,
#   'B00005AW1Y': 5,
#   'B00005NCA5': 7,
#   'B00005NN7B': 7,
#   'B00005V3FA': 2,
#   'B00005V6BP': 2,
#   'B0000640A2': 7,
#   'B00004XOMV': 7,
#   'B00005YVU0': 0,
#   'B00006409G': 2,
#   'B00006599O': 2,
#   'B00004TBGT': 2,
#   'B00001QEQ8': 3,
#   'B00004KDF9': 5,
#   'B000059O8B': 5,
#   'B000034DEA': 1,
#   'B00004TTHT': 5,
#   'B00005R2GW': 5,
#   'B00005UNWD': 2,
#   'B0000631W0': 2,
#   'B00004WYZH': 2,
#   'B00005V3EZ': 2,
#   'B00005V7E8': 3,
#   'B000038IFX': 2,
#   'B00005OMZV': 5,
#   'B00002SUPP': 5,
#   'B000069BD9': 2,
#   'B00005NUIZ': 0,
#   'B00005OLWW': 0,
#   'B00006409P': 0,
#   'B00001LAE2': 5,
#   'B00004T1MD': 5,
#   'B00002SVNY': 1,
#   'B0000488VP': 1,
#   'B00004YZAU': 1,
#   'B00005043P': 1,
#   'B000059Z7G': 1,
#   'B00004TJDI': 1,
#   'B000021XYY': 5,
#   'B00005A7FK': 5,
#   'B00005AT8B': 5,
#   'B00005NGS3': 5,
#   'B00001KUII': 5,
#   'B00001W0J2': 5,
#   'B00001XDKO': 5,
#   'B00002CF96': 5,
#   'B00004KHB2': 5,
#   'B00004Z0MH': 5,
#   'B00006F2EE': 0,
#   'B00004UE0O': 5,
#   'B00005BJ99': 2,
#   'B00005NN79': 2,
#   'B00005V5LP': 1,
#   'B00005V9NK': 0,
#   'B0000631WI': 0,
#   'B000063RRN': 5,
#   'B000066TSE': 5,
#   'B00004YKW3': 5,
#   'B00006LU9B': 3,
#   'B00002STH2': 5,
#   'B00004Y7SY': 5,
#   'B00005NSUQ': 5,
#   'B00000J97G': 1,
#   'B00001ZWPX': 3,
#   'B00002STUI': 3,
#   'B00002SVOG': 1,
#   'B00004R8V4': 3,
#   'B00004SW27': 3,
#   'B00004R9HO': 3,
#   'B00000F1GI': 5,
#   'B00005N7YU': 5,
#   'B00005NN5L': 2,
#   'B00005NN5J': 2,
#   'B00005OBQ2': 5,
#   'B00005WF9V': 5,
#   'B00001ZUL7': 6,
#   'B000035XZZ': 3,
#   'B00005TQ0X': 3,
#   'B000067DPE': 3,
#   'B00007DCEB': 2,
#   'B00005QB9K': 2,
#   'B0000631W8': 1,
#   'B00005NZ1L': 0,
#   'B00005NZ1T': 0,
#   'B00004WHW7': 5,
#   'B00005NBR0': 5,
#   'B00005V9QE': 5,
#   'B0008IST98': 5,
#   'B00004U5VN': 2,
#   'B000034DC2': 4,
#   'B00004KHDP': 5,
#   'B00004VUGN': 5,
#   'B000056KDZ': 5,
#   'B000066TSA': 0,
#   'B00005NCAG': 0,
#   'B00004U5VS': 2,
#   'B00005RCPR': 2,
#   'B00005QIR3': 5,
#   'B0000695HQ': 5,
#   'B00005NCAM': 2,
#   'B00005V9NI': 2,
#   'B00006JN5H': 5,
#   'B00005NCD0': 2,
#   'B00005V9NH': 2,
#   'B00005RCQY': 2,
#   'B00006471Z': 5,
#   'B00005V6BD': 2,
#   'B00004SA3J': 1,
#   'B00006409R': 0,
#   'B00000DMAR': 2,
#   'B00004TEXX': 2,
#   'B0000631VL': 0,
#   'B00005N9CQ': 2,
#   'B00005N7YS': 5,
#   'B000006P0J': 2,
#   'B00004W4S4': 2,
#   'B00002CF9M': 5,
#   'B00004WHWF': 5,
#   'B00005LOYC': 3,
#   'B0000695GX': 5,
#   'B00005LZNI': 2,
#   'B00005NH6G': 2,
#   'B0000657SM': 3,
#   'B00006LEM9': 1,
#   'B00006IJIW': 0,
#   'B00006LEMB': 2,
#   'B00004W4VH': 2,
#   'B00005A3I8': 5,
#   'B00004R9IK': 3,
#   'B00001SHNG': 0,
#   'B00005RL4E': 2,
#   'B00004U1R2': 3,
#   'B00005QX2X': 5,
#   'B00001R3XA': 5,
#   'B00006F2EC': 3,
#   'B0000664J8': 0,
#   'B000068NM5': 0,
#   'B00006FWU2': 0,
#   'B000040OEH': 5,
#   'B00005YO8Y': 3,
#   'B00005Q8LV': 5,
#   'B00005R5PX': 3,
#   'B00005R5PZ': 3,
#   'B00004KHB7': 5,
#   'B00005YTYK': 5,
#   'B00004UE0K': 5,
#   'B00004YLZM': 5,
#   'B00005QEFG': 3,
#   'B00005QEFM': 3,
#   'B000034DC7': 5,
#   'B00005O626': 0,
#   'B00005Q8KY': 0,
#   'B00005Y3ZW': 0,
#   'B00005NCCZ': 2,
#   'B00005QX4F': 5,
#   'B00004TTTQ': 2,
#   'B00004U8R2': 2,
#   'B00005OLWR': 2,
#   'B000063RRM': 2,
#   'B00006DY3H': 2,
#   'B00006LEM6': 2,
#   'B000035YBQ': 2,
#   'B00004SR5N': 1,
#   'B00005LIP8': 2,
#   'B00005V3F0': 0,
#   'B00004UDVL': 10,
#   'B000056PJE': 5,
#   'B000056PJI': 5,
#   'B00004U8KR': 5,
#   'B00005V6BJ': 0,
#   'B00006663Z': 5,
#   'B00003OPEQ': 5,
#   'B00005ULW9': 5,
#   'B00005QIQP': 5,
#   'B00006JN5J': 5,
#   'B00007B9N1': 5,
#   'B0000663U5': 5,
#   'B00006ZCCW': 1,
#   'B00005RZJA': 5,
#   'B000067DPH': 0,
#   'B000059Z7N': 2,
#   'B00005UOS4': 0,
#   'B00005YELX': 0,
#   'B000067K2C': 2,
#   'B000066JRG': 2,
#   'B00001X5CG': 2,
#   'B00005T7ZP': 2,
#   'B0000664J1': 2,
#   'B00006AN1F': 0,
#   'B00006JL1P': 2,
#   'B00004S9AC': 2,
#   'B00004SPW9': 2,
#   'B00004XMRL': 2,
#   'B00002STNQ': 5,
#   'B00004SUK6': 5,
#   'B00005O0I4': 0,
#   'B00005RVN8': 5,
#   'B000063LK3': 5,
#   'B00006409Y': 0,
#   'B00006LEMQ': 5,
#   'B00007E1OB': 5,
#   'B00000K3QV': 5,
#   'B00002EPGW': 5,
#   'B000056PJF': 5,
#   'B00004WLQV': 2,
#   'B00005MNRW': 0,
#   'B000070IW6': 3,
#   'B000065DGH': 5,
#   'B00006C260': 0,
#   'B000006P0K': 4,
#   'B00002ST27': 4,
#   'B00002ST3U': 4,
#   'B00004WLQ6': 4,
#   'B000035Y78': 2,
#   'B00005QJDS': 5,
#   'B00006LEM3': 0,
#   'B00006LELV': 0,
#   'B00006LEMA': 5,
#   'B00005TQG6': 3,
#   'B00005LOW9': 2,
#   'B00006C28Z': 2,
#   'B0000648AB': 3,
#   'B00000K11D': 1,
#   'B00000K2R5': 0,
#   'B00000SZZV': 1,
#   'B00004SR5M': 1,
#   'B00004T4XM': 1,
#   'B00004U3GL': 0,
#   'B00005NECC': 1,
#   'B00005QEFK': 3,
#   'B00005MIR3': 2,
#   'B00006LELB': 2,
#   'B00005NCB2': 2,
#   'B00005NN7J': 2,
#   'B00002STJH': 7,
#   'B00000I1C0': 12,
#   'B000038ABG': 12,
#   'B00005R5Q0': 6,
#   'B00006JN5G': 2,
#   'B00006LU9C': 0,
#   'B00003OPES': 5,
#   'B00005LBHM': 1,
#   'B00005V9NU': 1,
#   'B0000664J5': 1,
#   'B00000K2G7': 3,
#   'B00005V6B5': 1,
#   'B00007D02V': 2,
#   'B00005YVTZ': 3,
#   'B000067QW2': 3,
#   'B00006409H': 0,
#   'B00002EPY8': 0,
#   'B00004XRBB': 0,
#   'B00006JN5I': 0,
#   'B00006FDLH': 0,
#   'B000006OVE': 2,
#   'B00002SVX5': 2,
#   'B00002SVYB': 2,
#   'B000035Y76': 2,
#   'B00004TC6E': 2,
#   'B00005LOXE': 2,
#   'B00005OLWB': 2,
#   'B00005YO7I': 2,
#   'B0000657SN': 2,
#   'B00006FWTW': 1,
#   'B00004SRF5': 2,
#   'B00001ZWNA': 1,
#   'B00004U5VV': 2,
#   'B00004U5VP': 2,
#   'B00006FWSV': 0,
#   'B00004U8QM': 2,
#   'B00005NCA6': 2,
#   'B00005NCAN': 0,
#   'B000066EXR': 3,
#   'B000021Y5T': 6,
#   'B000029706': 7,
#   'B000066BZ1': 7,
#   'B00005NH6C': 7,
#   'B00001QER9': 3,
#   'B00004U4R9': 3,
#   'B00006LEMY': 3,
#   'B00002STGU': 3,
#   'B00004S9AA': 1,
#   'B00004TUF1': 3,
#   'B00004U1R0': 3,
#   'B00005ATSN': 4,
#   'B00005V3F1': 7,
#   'B000066TSC': 6,
#   'B00001IVR9': 5,
#   'B00005QI67': 0,
#   'B00002SVUI': 3,
#   'B00004LN2V': 3,
#   'B00004U62A': 3,
#   'B00005NUIR': 3,
#   'B00005OLX5': 2,
#   'B0000657SO': 2,
#   'B00005RCR2': 2,
#   'B00001LDCK': 5,
#   'B00004T77P': 4,
#   'B00004UDVU': 0,
#   'B00007UHR7': 2,
#   'B00002STXS': 7,
#   'B00002SW3O': 7,
#   'B00002SVF6': 7,
#   'B000035XGF': 7,
#   'B000035XFY': 7,
#   'B000035Y5Q': 7,
#   'B00004SVS5': 7,
#   'B00004SVS6': 7,
#   'B00004SVS4': 7,
#   'B00004SVXG': 7,
#   'B00004SVS7': 7,
#   'B0000657SQ': 0,
#   'B00005RHQZ': 5,
#   'B000069CEB': 5,
#   'B00005V9NS': 2,
#   'B0000664JG': 3,
#   'B00005UJSA': 0,
#   'B00005V6BR': 1,
#   'B000066JRQ': 2,
#   'B00006AVAZ': 0,
#   'B0000524R7': 2,
#   'B00005Q8IW': 2,
#   'B00005QDPT': 3,
#   'B00005R5PT': 6,
#   'B00005R5PU': 6,
#   'B00005V8TW': 5,
#   'B0000631VQ': 2,
#   'B00005RH4H': 2,
#   'B00005ME6E': 7,
#   'B00005QDPX': 2,
#   'B00006C296': 0,
#   'B00000K514': 5,
#   'B00004U8KO': 5,
#   'B00004VXAZ': 5,
#   'B00005B4AS': 5,
#   'B000065SQ5': 5,
#   'B000067FPP': 5,
#   'B00005AG0S': 5,
#   'B00005S0OV': 0,
#   'B000066TS4': 2,
#   'B000066TS7': 0,
#   'B00005NOFH': 2,
#   'B000066RK6': 0,
#   'B000066TS1': 1,
#   'B00005NCA9': 2,
#   'B00006F7S8': 3,
#   'B00006FXJG': 5,
#   'B00006GSO1': 0,
#   'B0000690P7': 5,
#   'B00006CRW5': 5,
#   'B00000IODY': 2,
#   'B00003E4G6': 2,
#   'B00004R9IG': 2,
#   'B000034DCF': 2,
#   'B00005CFHN': 1,
#   'B00006RHM1': 0,
#   'B00007B77T': 0,
#   'B00006LEMK': 2,
#   'B00005KAAZ': 2,
#   'B00000INR2': 3,
#   'B00004TBC0': 5,
#   'B000056KDV': 5,
#   'B00006CRUN': 5,
#   'B00002R17B': 5,
#   'B00006C2HA': 3,
#   'B00005YKL1': 2,
#   'B000068U1F': 5,
#   'B00006AALC': 5,
#   'B00006CRVH': 2,
#   'B000006RGS': 11,
#   'B000006RGR': 11,
#   'B00002SFNG': 11,
#   'B00002K13U': 11,
#   'B00002SA3S': 11,
#   'B00004NS10': 11,
# ...
#   'B01AZ5NOPC': 13,
#   'B00DDXILBQ': 11,
#   'B00IQCRKW0': 13,
#   'B00KO97D8Y': 15,
#   'B013H0ISW6': 24,
#   'B01FMQ3MGU': 9,
#   'B01FSK99PS': 0,
#   'B00BGA9X9W': 5,
#   'B00MUTAU4A': 18,
#   'B00NQT48L4': 18,
#   'B00T3452AW': 18,
#   'B00VMB5VCS': 18,
#   'B0174V97Q0': 18,
#   'B00DBDPOZ4': 30,
#   'B01ENZU6J2': 30,
#   'B01GKGVI9Y': 30,
#   'B000035Y6D': 21,
#   'B00002ST6R': 21,
#   'B00002SVYB': 21,
#   'B000035Y09': 21,
#   'B00004SVX5': 21,
#   'B0093FQ9KI': 21,
#   'B00FLLFJOU': 30,
#   'B00VU4J13W': 5,
#   'B01DPS4QQ2': 5,
#   'B01GW3NY5Q': 5,
#   'B018GUYOMU': 5,
#   'B01DX7S0LW': 2,
#   'B0009XBWY6': 2,
#   'B00DB9JV5W': 24,
#   'B01DYATFOY': 15,
#   'B01FSO3X2Y': 15,
#   'B00002STSW': 15,
#   'B0000664JE': 15,
#   'B000FRU1UM': 15,
#   'B00149PCAO': 15,
#   'B001PB9J14': 15,
#   'B002BRZ8FW': 15,
#   'B00BGA9YZK': 15,
#   'B00I0574CO': 15,
#   'B00N23Z8PO': 15,
#   'B00NLZABBE': 13,
#   'B00SXEONTY': 24,
#   'B01D9T0BAC': 13,
#   'B01EJNUMQ0': 13,
#   'B002BSA388': 14,
#   'B005FYJA52': 14,
#   'B01F9B019Y': 0,
#   'B0050SYDEQ': 5,
#   'B01GW90BTW': 24,
#   'B01EM9PLX0': 0,
#   'B01EM9PLVC': 0,
#   'B01EYCLJ04': 0,
#   'B0132YMS50': 18,
#   'B015UA1NBO': 4,
#   'B01H1GJ7IQ': 5,
#   'B00AXE639A': 30,
#   'B013LED6JI': 18,
#   'B00MNPDMEQ': 20,
#   'B014FZYV3C': 12,
#   'B014KXMLZ4': 4,
#   'B017W17G1U': 4,
#   'B017W177FK': 4,
#   'B01BHL3OH6': 4,
#   'B0013RATNM': 1,
#   'B00OAYHIRA': 8,
#   'B019WRM1IA': 13,
#   'B000VVEMXY': 0,
#   'B01CJJIQ46': 0,
#   'B01F074HKG': 5,
#   'B0053B5RGI': 0,
#   'B00RHI62IW': 0,
#   'B000IONGVI': 13,
#   'B001SIFNXW': 13,
#   'B004M8K9AW': 13,
#   'B00DWXV074': 13,
#   'B00M4L9H52': 13,
#   'B00TFSRVBY': 0,
#   'B00AAS888S': 0,
#   'B00JF63SQI': 0,
#   'B00MYTSDU4': 0,
#   'B00C1ZBFTW': 4,
#   'B00PV515DU': 4,
#   'B01BF74KOS': 4,
#   'B01GW3PZW6': 4,
#   'B00SULMRI4': 0,
#   'B00WJ1HONE': 0,
#   'B0053BCO00': 19,
#   'B000SFK0QQ': 19,
#   'B00DWXV07E': 19,
#   'B00DU2CHE2': 0,
#   'B00EZPCX1A': 25,
#   'B00ZS1SRO2': 0,
#   'B00ZSGHIGK': 0,
#   'B00000I1BA': 26,
#   'B00002SVP7': 26,
#   'B00005C4JM': 26,
#   'B000J42FMI': 26,
#   'B00ZQC73O8': 5,
#   'B0188YF39W': 5,
#   'B01GW3P9PE': 5,
#   'B00UO4NKA4': 5,
#   'B00ZM6HOCO': 5,
#   'B00ZM5OXD8': 5,
#   'B002BRUTT2': 25,
#   'B00KVSQAGO': 24,
#   'B00ZJEW57S': 24,
#   'B01AKPIYCA': 24,
#   'B00JUFT3L8': 24,
#   'B00YX2HFCW': 24,
#   'B00CMSCT8Y': 0,
#   'B016K08OHY': 0,
#   'B00IRHE892': 0,
#   'B00ZPZQKIG': 30,
#   'B0000296O5': 6,
#   'B00002R28C': 6,
#   'B00004Y57G': 6,
#   'B00005LOXE': 6,
#   'B00020BV2E': 6,
#   'B000BAVN14': 6,
#   'B006IOAHTQ': 17,
#   'B00DHF39L2': 17,
#   'B00Q5JD2DM': 0,
#   'B00SAYCVTQ': 0,
#   'B017L187YG': 0,
#   'B007XVTR12': 9,
#   'B00D4WTO1M': 5,
#   'B00QXJFDZO': 5,
#   'B0050SYILE': 11,
#   'B000051QDD': 11,
#   'B00005CFA0': 11,
#   'B00006FWU6': 11,
#   'B00008XL07': 11,
#   'B000093NQI': 11,
#   'B0000DI6BB': 11,
#   'B00012D0SG': 14,
#   'B00012YI14': 11,
#   'B00020LZAW': 11,
#   'B0002I9RQ8': 11,
#   'B000809P9O': 11,
#   'B0009350BM': 11,
#   'B0009350BW': 11,
#   'B00095LEDS': 11,
#   'B0009I9EO6': 11,
#   'B000AMJVDA': 11,
#   'B000F6BGXY': 11,
#   'B000KCX9M4': 11,
#   'B000N60GPA': 11,
#   'B000NJH6RS': 11,
#   'B000OCXK6A': 11,
#   'B000P297F2': 11,
#   'B000TG530M': 11,
#   'B000TG72TW': 11,
#   'B000ZK696O': 11,
#   'B0014FMHEW': 11,
#   'B001AWFIPO': 11,
#   'B001AWFIMW': 11,
#   'B001AZFSFQ': 11,
#   'B0022TNO7S': 11,
#   'B002MED6F8': 11,
#   'B003O6JKLC': 11,
#   'B0045EI7I4': 11,
#   'B0053BQQ6I': 11,
#   'B01H482N6E': 27,
#   'B014ASB308': 27,
#   'B01EJ9DMQQ': 5,
#   'B014R4ZXXI': 9,
#   'B01GVE4ZXQ': 5,
#   'B007IQ2Y2G': 4,
#   'B0081FKLLO': 18,
#   'B00TS0UFNK': 18,
#   'B00BU3ZLJQ': 5,
#   'B0088MVOES': 7,
#   'B00ECOBFA4': 7,
#   'B00KJ8UPDA': 7,
#   'B019H4DSI0': 0,
#   'B01FZ3BR5S': 0,
#   'B0050SVNZ8': 13,
#   'B00XWQZP9K': 5,
#   'B01GW3POY0': 5,
#   'B0012NAPNQ': 5,
#   'B00SN1QEGW': 17,
#   'B01AC3ZDCE': 13,
#   'B00M88KB7Y': 13,
#   'B01FY2U3UK': 13,
#   'B00ZJBSCJQ': 5,
#   'B0050SVNSU': 25,
#   'B017WJY9V2': 25,
#   'B017WJY65Q': 25,
#   'B017WJYCZA': 0,
#   'B000FQ2DTA': 9,
#   'B000HWX418': 9,
#   'B0021TVYCG': 9,
#   'B002BRZ79E': 9,
#   'B0062VM8LU': 9,
#   'B01CKH0XQ6': 18,
#   'B00ZSHRPN0': 4,
#   'B016NEVPZ0': 18,
#   'B01AC3ZACC': 14,
#   'B01CKH0XZM': 18,
#   'B00CJ7IUI6': 23,
#   'B00WTI3JPE': 23,
#   'B00YQ2KCWO': 5,
#   'B000R2XJJK': 23,
#   'B00140P9BA': 23,
#   'B001CWXAP2': 23,
#   'B001GO7DX6': 23,
#   'B0028IBTLG': 23,
#   'B002BXKJA0': 23,
#   'B0051BH6FK': 23,
#   'B0064TYOLW': 23,
#   'B0065NP05G': 23,
#   'B006YDPU48': 23,
#   'B00DS0MQUQ': 9,
#   'B00000I1C0': 9,
#   'B000059L4Q': 28,
#   'B00B1VJZNK': 28,
#   'B00E4MQODC': 0,
#   'B01AGEYZ1O': 5,
#   'B00O9GP99S': 18,
#   'B00O9GPD26': 18,
#   'B00O9GPAVU': 18,
#   'B00SX51GAM': 18,
#   'B000VWQWHC': 15,
#   'B003WU3CDW': 15,
#   'B00E6LHQX8': 15,
#   'B00L3D7R86': 15,
#   'B00007UHJY': 6,
#   'B00009OWKQ': 6,
#   'B0000TSRA6': 6,
#   'B0002IQD1U': 6,
#   'B0009UUQFK': 6,
#   'B00DYAQHTQ': 0,
#   'B00MMTKXTA': 0,
#   'B003KM38EK': 1,
#   'B00KAED850': 5,
#   'B0039O2TX0': 1,
#   'B009D3HSTG': 1,
#   'B01CDCG4KM': 0,
#   'B01GW3H3U8': 0,
#   'B01GW913DU': 5,
#   'B017AGIDY6': 0,
#   'B00CQ35C1Q': 0,
#   'B00TKFD51M': 0,
#   'B0028V0RY8': 29,
#   'B01GKGVIB2': 5,
#   'B01307Q6ZC': 4,
#   'B0024ZT3XO': 19,
#   'B00FXOP1JI': 19,
#   'B00G0OYHCW': 19,
#   'B014W1YLAM': 0,
#   'B01D8H09LQ': 0,
#   'B019H5II8Y': 12,
#   'B00CX6XKK6': 30,
#   'B00CX8VYM0': 30,
#   'B00GLZQR96': 5,
#   'B00KSQHX1K': 30,
#   'B00ZMBMO06': 30,
#   'B004NRN5DU': 30,
#   'B0050SY4DG': 30,
#   'B0050SYX8W': 1,
#   'B00WOK8Z74': 30,
#   'B01DM98L7O': 30,
#   'B00004SVVT': 1,
#   'B000A0EFJW': 1,
#   'B000FRS9II': 1,
#   'B000MEA9TQ': 1,
#   'B000SQ5LQ4': 1,
#   'B000ZK9QD2': 1,
#   'B001ASJIRM': 1,
#   'B001D7T2VM': 1,
#   'B001HWB68K': 1,
#   'B002BRZ852': 1,
#   'B002BSA1MQ': 1,
#   'B002EE5ROO': 1,
#   'B002GCDLLK': 1,
#   'B0037LTTRO': 1,
#   'B004PAGJOC': 1,
#   'B0050SY77E': 1,
#   'B0050SY5BM': 1,
#   'B0056WJA30': 1,
#   'B005C2D2MO': 1,
#   'B005GM3Y5U': 1,
#   'B00BG6ZHL4': 1,
#   'B00CP1UQPG': 1,
#   'B00EFFW0HC': 1,
#   'B00KME8KFG': 1,
#   'B00L6AVPMU': 1,
#   'B0009Z3MQ0': 31,
#   'B000X25GWC': 31,
#   'B008U2XEL2': 20,
#   'B00F27JGVA': 4,
#   'B0009351R0': 2,
#   'B01ELQGLRY': 2,
#   'B01GW8ZC2O': 29,
#   'B000MJB0H6': 6,
#   'B00KI2OZ9M': 6,
#   'B0007QRKA0': 6,
#   'B00BTNT4G8': 6,
#   'B00NTSYCFO': 6,
#   'B00IVJ1M7M': 0,
#   'B000047GEI': 0,
#   'B00005BOS7': 0,
#   'B00005LBHM': 0,
#   'B007JDMPOK': 0,
#   'B00006IKB6': 1,
#   'B001CBW18K': 1,
#   'B002W5GI9I': 1,
#   'B01E8P52DW': 0,
#   'B00EDU8H9E': 12,
#   'B00ZZIF0JS': 12,
#   'B015PII6YI': 12,
#   'B00ZQ17PL0': 12,
#   'B01GW3OAPE': 12,
#   'B00Y4S5KPY': 0,
#   'B00ZDNNRB8': 0,
#   'B00SBXBQDS': 0,
#   'B000P46NMA': 5,
#   'B001AWBYNE': 32,
#   'B003VUO6H4': 5,
#   'B0050SWZHS': 5,
#   'B0053BSOD6': 32,
#   'B005N4HBE6': 12,
#   'B00D9EPI38': 12,
#   'B00MAPYKPO': 12,
#   'B000B6MLV4': 12,
#   'B000WMEEAI': 12,
#   'B00DBCAT3W': 12,
#   'B00CTKHXFO': 5,
#   'B00GU8W5AE': 5,
#   'B00Z7V9P8K': 5,
#   'B016P6KIFY': 5,
#   'B0050SWUTQ': 3,
#   'B005YR308S': 5,
#   'B00DBM1RVA': 5,
#   'B00IQCRKT8': 5,
#   'B018RKS1TG': 5,
#   'B00FLLFJ68': 22,
#   'B00NMST9G8': 22,
#   'B00NQT48NM': 22,
#   'B000066TS5': 8,
#   '9629971372': 8,
#   'B00001IVB4': 8,
#   'B00005Q8LR': 8,
#   'B00005Q8LY': 8,
#   'B00005YVTY': 8,
#   'B000066JRN': 8,
#   'B000067DPM': 8,
#   'B00006YXLE': 8,
#   'B000088KHF': 8,
#   'B00020BV0Q': 8,
#   'B00027CXEM': 8,
#   'B0002B90SA': 8,
#   'B0009Z3HZQ': 8,
#   'B000F9JFXE': 8,
#   'B004SOZC02': 8,
#   'B00DBF829C': 5,
#   'B00X8Y18U6': 5,
#   'B007XVTR3K': 12,
#   'B00VU4J8YY': 13,
#   'B01F9HMO9S': 13,
#   'B000TI836G': 2,
#   'B00CXCCB64': 13,
#   'B01H1WR47G': 5,
#   'B016KBVBCS': 0,
#   'B01FXD3BTK': 5,
#   'B00AZGC3VI': 21,
#   'B00BPANZ60': 21,
#   'B00C9UND8U': 21,
#   'B00NJ0HTH0': 17,
#   'B0171RL3RS': 14,
#   'B01AC3ZD06': 17,
#   'B01AC3ZGRG': 17,
#   'B006JKAS16': 17,
#   'B00P82JMV8': 24,
#   'B00T55HUO0': 0,
#   'B000AQA9UA': 34,
#   'B000H77DFG': 34,
#   'B01GW8YDLK': 5,
#   'B00C7103C0': 13,
#   'B00GBCLG0E': 13,
#   'B01CYYFWW0': 9,
#   'B01FJAL4LE': 0,
#   'B00198PO5I': 9,
#   'B0002OOUWI': 8,
#   'B0002OOUZU': 8,
#   'B0050SYY5E': 8,
#   'B0067O5SBE': 9,
#   'B00HGLLRV2': 5,
#   'B00D781Q9G': 5,
#   'B00004C8S0': 15,
#   'B00005QB9O': 15,
#   'B004UJNN5G': 15,
#   'B00BMFIXZG': 9,
#   'B00CM7ZRJS': 15,
#   'B00MUTAU18': 15,
#   'B00SZ6OTX0': 15,
#   'B019OB663A': 0,
#   'B01ADD49XM': 0,
#   'B000IX1NDC': 0,
#   'B000JGKDMU': 0,
#   'B0096PSFBG': 15,
#   'B00FAS1WDG': 0,
#   'B00PB9LZQI': 17,
#   'B000QJ1NS8': 35,
#   'B00OXT57A2': 35,
#   'B00KVSQ848': 5,
#   'B00Z9LUDX4': 5,
#   'B013H0IRO0': 5,
#   'B00I19TYW2': 5,
#   'B00R9NWEFK': 5,
#   'B00RHI62GY': 9,
#   'B013HMN66M': 5,
#   'B00BGA9WK2': 5,
#   'B01FT72NOO': 24,
#   'B00ZM6I932': 17,
#   'B01ESA0W96': 4,
#   'B0118GJKIW': 18,
#   'B011I4AQWI': 18,
#   'B011I4APHY': 18,
#   'B0128UGFLM': 18,
#   'B016XIA2FK': 18,
#   'B01BYKK1PI': 18,
#   'B01CKH0W94': 18,
#   'B01CKH0WBC': 18,
#   'B01H2DKHSM': 18,
#   'B01H2DKGZQ': 18,
#   'B00077VDS4': 36,
#   'B000GHK3TA': 36,
#   'B000KQQUMQ': 36,
#   'B000N24EO8': 36,
#   'B000PS1HNQ': 36,
#   'B000TPTCPU': 36,
#   'B000VSEF52': 36,
#   'B001444IN6': 36,
#   'B0019HXJ5Q': 36,
#   'B001AIR1F8': 36,
#   'B002OPZTHI': 36,
#   'B00L59D9HG': 5,
#   'B00K2O4O6K': 17,
#   'B014GXYL8S': 17,
#   'B017EI5BK4': 17,
#   'B01GF9L1T8': 17,
#   'B0136JP894': 5,
#   'B01G7TX04K': 5,
#   'B00HVBPRUO': 5,
#   'B00KY1HZ80': 9,
#   'B00SXANENY': 20,
#   'B00TKTHZB4': 20,
#   'B00KVR4HEC': 9,
#   'B002AB7TX8': 5,
#   'B00Q03M3HY': 9,
#   'B000023MD4': 14,
#   'B005WMIR4C': 14,
#   'B00O9GW8VK': 18,
#   'B00002ST7F': 14,
#   'B00002SVNY': 14,
#   'B000035XLL': 14,
#   'B00005C9F6': 14,
#   'B00009WAVB': 14,
#   'B0000B0MNC': 14,
#   'B00095LEC4': 14,
#   'B000ERVMI8': 14,
#   'B0013B30SE': 14,
#   'B001DKDANA': 14,
#   'B00GAC1D2G': 5,
#   'B00FRESTZW': 9,
#   'B00IAVDQCK': 13,
#   'B00K308KF4': 30,
#   'B00KAED7OC': 15,
#   'B00M221FOE': 13,
#   'B014W3FGYU': 0,
#   'B00CM1KU82': 30,
#   'B01APA8D2G': 0,
#   'B019JFB62M': 17,
#   'B01DJPA9YE': 17,
#   'B00CIBCTLC': 5,
#   'B00WP4LM3I': 5,
#   'B017W17G4M': 5,
#   'B004IK24MU': 20,
#   'B0181R6WUA': 20,
#   'B0016QCCFS': 20,
#   'B001CPBM6S': 20,
#   'B01GKF824Y': 0,
#   'B00DBF813Y': 24,
#   'B00005O0I9': 24,
#   'B00005Q5CW': 24,
#   'B00009YFU2': 24,
#   'B0000BY1ZS': 24,
#   'B00068O1K6': 24,
#   'B00178630A': 24,
#   'B00ZJ211Q6': 24,
#   'B000NUIYK0': 30,
#   'B0017HQDUG': 30,
#   'B001ABP95E': 30,
#   'B001M5I4GO': 30,
#   'B001N791HC': 30,
#   'B0028ZJ4O8': 30,
#   'B00FRESY4I': 5,
#   'B014N4RTS4': 5,
#   'B00XO24FHA': 37,
#   'B01BSQV64I': 37,
#   'B01GW917NQ': 37,
#   'B001383L2M': 3,
#   'B002DY9KHU': 3,
#   'B01GUI94NO': 9,
#   'B00020V5B6': 2,
#   'B000FW87AI': 2,
#   'B00AZWE7ES': 2,
#   'B00BU3WVM6': 2,
#   'B01D63UU52': 0,
#   'B015VP5EOK': 0,
#   'B00ZGPJ30M': 0,
#   'B00KWHOXGI': 18,
#   'B00KWHJ0KC': 18,
#   'B00YZ3V1EW': 18,
#   'B00ZSJU97C': 18,
#   'B013HMN5W2': 9,
#   'B00IA2O0W4': 38,
#   'B0188JBLBG': 38,
#   'B00LX8N14A': 9,
#   'B006QRMR4S': 9,
#   'B00NLZAB6E': 9,
#   'B004UMAPRW': 8,
#   'B0050SYE40': 8,
#   'B0050SY8UK': 8,
#   'B0053BG370': 8,
#   'B0056BE0XG': 8,
#   'B005GWU110': 8,
#   'B005HO2GYW': 8,
#   'B015XC3B46': 18,
#   'B00ZPQZMUM': 5,
#   'B00KVQYJR8': 5,
#   'B00PE1KNPC': 5,
#   'B01D9T0A1C': 5,
#   'B01GKF7T9S': 5,
#   'B01BG1O75A': 0,
#   'B01G2F0LPU': 0,
#   'B015WKY3IM': 25,
#   'B000WMEEBC': 5,
#   'B004FS8LYK': 5,
#   'B0050JN84Q': 5,
#   'B0050JN7ZG': 5,
#   'B0050SXX88': 5,
#   'B006JKARNU': 5,
#   'B006JKARU8': 5,
#   'B00GMFKYK8': 5,
#   'B0073QM3SG': 29,
#   'B000U34SZA': 10,
#   'B003O6E7DI': 10,
#   'B003YHJJW6': 25,
#   'B006ZPAYD2': 5,
#   'B00004UFRI': 39,
#   'B0000503QB': 39,
#   'B00005A4X6': 39,
#   'B0009XBXQ8': 39,
#   'B000AOEUYS': 39,
#   'B000E0OCQY': 39,
#   'B000E0OCR8': 39,
#   'B000FVM49Y': 39,
#   'B000G79VKC': 39,
#   'B000MGR686': 39,
#   'B000MLC69U': 39,
#   'B000MR5OBQ': 39,
#   'B000QSVMRG': 39,
#   'B000RF17YG': 39,
#   'B000SSPH3E': 39,
#   'B000SSQPU8': 39,
#   'B000UHD85C': 39,
#   'B000XJLQ24': 39,
#   'B00136MBHA': 39,
#   'B00149I2ME': 39,
#   'B0015A8RQ8': 39,
#   'B001AF1NVY': 39,
#   'B001BJ68Y6': 39,
#   'B001COTC3E': 39,
#   'B001E27DLM': 39,
#   'B001F513VO': 39,
#   'B0001NBNEI': 11,
#   'B01ESA0W3C': 11,
#   'B01GOK1H06': 11,
#   'B019ETYAZI': 5,
#   'B01EF2J644': 22,
#   'B001COV1CY': 9,
#   'B002ELCV00': 9,
#   'B0060WDIXI': 9,
#   'B01G2F0LPA': 9,
#   'B00DHF39HQ': 5,
#   'B01GTL4YSW': 5,
#   'B01DX7S4KE': 2,
#   'B00QE1XH8Q': 0,
#   'B00FNKMVUO': 21,
#   'B01AZC3III': 10,
#   'B000LV9N8S': 40,
#   'B0050SYWVA': 40,
#   'B00005QDPZ': 8,
#   'B000069BB0': 8,
#   'B0009WPZPE': 8,
#   'B000HKKM2Y': 8,
#   'B009EPQ45W': 8,
#   'B00K2O4O5G': 8,
#   'B00ZGRLMNQ': 3,
#   'B003ZSN600': 5,
#   'B00E369SDM': 5,
#   'B000FRU0NU': 11,
#   'B0016B28Y8': 11,
#   'B01BQ91U9I': 0,
#   'B01GDKXMPA': 0,
#   'B00HYPWE8A': 5,
#   'B00000IJVY': 41,
#   'B00008DHNL': 41,
#   'B000095ZH5': 41,
#   'B0002Y2XXQ': 41,
#   'B0006G4KRC': 41,
#   'B0009Z3HXI': 41,
#   'B000A5K5MI': 41,
#   'B000GTVJPK': 41,
#   'B002B9FIUU': 12,
#   'B015P2GQQY': 12,
#   'B00ZJEIS2Y': 13,
#   'B015HAL2OA': 18,
#   'B01H6GUCCQ': 18,
#   'B002ACOJTY': 18,
#   'B00O9GP95W': 18,
#   'B00RHI62OG': 18,
#   'B00RHI62N2': 18,
#   'B00TS0UFAS': 18,
#   'B00TUFUD0S': 18,
#   'B00Y074JD8': 18,
#   'B014GEEZLA': 18,
#   'B017V7DIGW': 11,
#   'B01CG8UQPM': 18,
#   'B01H2DKHCS': 18,
#   'B01E8RS598': 0,
#   'B01DBL9IC0': 24,
#   'B009I6FWOQ': 21,
#   'B00GQD4GJ6': 21,
#   'B00004ZCP0': 42,
#   'B00005ME3J': 42,
#   'B00004TN9O': 2,
#   'B00019HNNC': 2,
#   'B01A9UATJC': 4,
#   'B01AVLWBY0': 4,
#   'B012F20ZU0': 4,
#   'B014KXMLXG': 4,
#   'B017C7AUXK': 4,
#   'B00002SVF4': 7,
#   'B014GBNNT8': 7,
#   'B01CDYB8F6': 30,
#   'B00LCHZRIK': 17,
#   'B00HKPSVIG': 17,
#   'B000LSJKAM': 14,
#   'B006QRNKOO': 25,
#   'B01AC3ZE5K': 14,
#   'B01GWGX74Q': 4,
#   'B005IGPY48': 14,
#   'B016NV4NUM': 14,
#   'B00GZ1H07Y': 5,
#   'B0166QDJDQ': 5,
#   'B014W1YU6M': 5,
#   'B00KSVXSZU': 0,
#   'B00M3D8IPQ': 24,
#   'B001REZLY8': 22,
#   'B00063BLG8': 10,
#   'B000B6MLS2': 10,
#   'B000B6MLUA': 10,
#   'B000B6MLTG': 10,
#   'B000B6MLSC': 10,
#   'B000B9RI00': 10,
#   'B000BWZY7Q': 10,
#   'B000FO4KO8': 10,
#   'B000OYMYZQ': 10,
#   'B000OYITQO': 10,
#   'B000TG531G': 10,
#   'B000VJTJNE': 10,
#   'B000ZKA0J6': 10,
#   'B0014CFO4K': 10,
#   'B001G8YV6Y': 10,
#   'B001O5CCQK': 10,
#   'B0029LJIFG': 10,
#   'B002BCXALQ': 10,
#   'B003CP0BHM': 10,
#   'B005WWZUQ0': 10,
#   'B00ARD5410': 10,
#   'B00WJ0Z10S': 18,
#   'B01BCMBK1W': 9,
#   'B01H74VPX2': 25,
#   'B000XJS00K': 15,
#   'B000XYFY3Q': 15,
#   'B0014G98WA': 15,
#   'B001KWFBG0': 15,
#   'B001PKHRVE': 15,
#   'B001YI0Z2U': 6,
#   'B0030MOTNE': 15,
#   'B003DZ4F64': 15,
#   'B004BD1DWG': 15,
#   'B004CD9X2C': 15,
#   'B0050SYZCQ': 15,
#   'B005J5K9EI': 15,
#   'B00U2E28YA': 7,
#   'B00UI0JKW6': 7,
#   'B0186D1TYS': 7,
#   'B00EADTVLW': 24,
#   'B01GT0UN8S': 24,
#   'B00002STPG': 6,
#   'B00005BW7Q': 6,
#   'B00005UNWC': 6,
#   'B000CN750I': 6,
#   'B017V7DMI6': 5,
#   'B001KMRN0M': 23,
#   'B0007TFLLM': 23,
#   'B000E9TDGO': 23,
#   'B000ERVLZC': 23,
#   'B000UVZWYS': 23,
#   'B00ZPT59YS': 15,
#   'B01CVRVYFE': 15,
#   'B00005B70T': 15,
#   'B00006C28U': 15,
#   'B0000E3D8T': 15,
#   'B0001I9YE4': 15,
#   'B0001JXQ5Q': 15,
#   'B0009UC6AI': 15,
#   'B000MIO1GY': 15,
#   'B001TOMQVC': 15,
#   'B0194HDD26': 15,
#   'B017LWQQWK': 0,
#   'B01AUQETOG': 0,
#   'B01H6SM5CY': 0,
#   'B013VO61O0': 30,
#   'B019II3I4E': 30,
#   'B00005RCPR': 7,
#   'B018F6NSP4': 7,
#   'B0176NK6D4': 0,
#   'B003ZSP0WW': 19,
#   'B000PD0HQE': 19,
#   'B0069EB9CY': 19,
#   'B006Y4GQ4K': 19,
#   'B00XR3YBFW': 24,
#   'B012DFI02O': 5,
#   'B00YDV70NW': 13,
#   'B011XO54MA': 13,
#   'B016WRQCKQ': 24,
#   'B0186BNC68': 24,
#   'B017W16ZUI': 5,
#   'B004K1EA5Q': 13,
#   'B014SKR9H4': 20,
#   'B0041RR0TW': 0,
#   'B015YE7HBQ': 0,
#   'B019BGXIM0': 0,
#   'B00AEWTSWU': 0,
#   'B00SMCJB4Y': 11,
#   'B015Q50FA8': 11,
#   'B000UU3SVI': 11,
#   'B000W91EN6': 11,
#   'B00130AIQM': 11,
#   'B0014X7SQ6': 23,
#   'B002B1TDV8': 23,
#   'B000B9RI14': 21,
#   'B000UB3B3W': 21,
#   'B00269QLJ2': 21,
#   'B003IEBO9Q': 21,
#   'B004XGN8W4': 21,
#   'B00R9NWEFA': 43,
#   'B0009R1TAO': 43,
#   'B019FEWBM6': 43,
#   'B00BJEY9EO': 44,
#   'B00BKWZ18I': 44,
#   'B00HAZ6IA4': 44,
#   'B00XXVFOAO': 44,
#   'B00MG654FM': 0,
#   'B013VO6FE6': 0,
#   'B007CS9WYI': 0,
#   'B00ZTRW00C': 5,
#   'B00XR3YBM0': 5,
#   'B00XWE60G4': 5,
#   'B010U1DNE8': 4,
#   'B00P8EMB5A': 22,
#   'B01GKGVI8U': 5,
#   'B00LO53FY8': 5,
#   'B00CX8VY4S': 22,
#   'B017V6Y34E': 5,
#   'B0140Z6T3W': 24,
#   'B0050SZ980': 13,
#   'B00KAI3KW2': 13,
#   'B00YQ1NOPM': 13,
#   'B0047THYWC': 9,
#   'B00JUFT1G0': 24,
#   'B004TTNTYW': 12,
#   'B00EO6GSY8': 12,
#   'B00Z9LTDFS': 5,
#   'B00D7TYIY0': 45,
#   'B016E70C6O': 45,
#   'B00PDRZFYG': 30,
#   'B014X427WM': 21,
#   'B0153XBEBM': 11,
#   'B001CPFPJ8': 21,
#   'B00ZM6I1DU': 4,
#   'B01GW8VG7O': 30,
#   'B00NASF4PA': 12,
#   'B00Z0UWWYC': 0,
#   'B00KX75W9O': 0,
#   'B00U1WN17G': 0,
#   'B014US02ZA': 0,
#   'B014US043A': 0,
#   'B00005QWWD': 25,
#   'B000KKRDBY': 25,
#   'B000O5RHZW': 25,
#   'B000SMIUQQ': 25,
#   'B00YXO5UI6': 5,
#   'B018WJZKBY': 5,
#   'B004YVOCYG': 5,
#   'B01DYATEMW': 5,
#   'B00020LZC0': 46,
#   'B00023JJUW': 46,
#   'B00NMS0YYO': 5,
#   'B000CEXDWG': 30,
#   'B001EYU1W8': 30,
#   ...}}

# %%
def recommend_game_for_year(game_id, year, df, all_graphs, all_partitions, top_n=5):

    if year not in all_graphs:
        return f"❌ Année {year} non disponible"

    G = all_graphs[year]
    partition = all_partitions[year]

    if game_id not in partition:
        return f"❌ Le jeu {game_id} n’existe pas dans l’année {year}"

    # Communauté du jeu
    comm = partition[game_id]

    # Jeux de cette communauté
    comm_games = [g for g, c in partition.items() if c == comm]

    # Trier par popularité (degree)
    sorted_games = sorted(
        [g for g in comm_games if g != game_id],
        key=lambda g: G.degree(g),
        reverse=True
    )

    return sorted_games[:top_n]

# %%
game_id = "B003ZSP0WW"

all_recommendations = {}

for year in sorted(all_graphs.keys()):
    recs = recommend_game_for_year(game_id, year, df, all_graphs, all_partitions)
    all_recommendations[year] = recs

all_recommendations
# Out:
# {np.int64(1999): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 1999',
#  np.int64(2000): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2000',
#  np.int64(2001): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2001',
#  np.int64(2002): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2002',
#  np.int64(2003): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2003',
#  np.int64(2004): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2004',
#  np.int64(2005): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2005',
#  np.int64(2006): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2006',
#  np.int64(2007): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2007',
#  np.int64(2008): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2008',
#  np.int64(2009): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2009',
#  np.int64(2010): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2010',
#  np.int64(2011): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2011',
#  np.int64(2012): '❌ Le jeu B003ZSP0WW n’existe pas dans l’année 2012',
#  np.int64(2013): ['B000IMYKQ0',
#   'B000FQ9R4E',
#   'B000IMWK2G',
#   'B0009VXBAQ',
#   'B0050SWSQQ'],
#  np.int64(2014): ['B002I0H79C',
#   'B000P46NMK',
#   'B0050SYX8W',
#   'B00BMFIXT2',
#   'B0029LJIFG'],
#  np.int64(2015): ['B0050SYILE',
#   'B00BU3ZLJQ',
#   'B000FRU0NU',
#   'B002BSA20M',
#   'B000P46NMK'],
#  np.int64(2016): ['B00DB9JV5W',
#   'B00CMQTTZ2',
#   'B00YJJ0OQS',
#   'B00YQ1NOPM',
#   'B00ZB7W4QU'],
#  np.int64(2017): ['B00JA81WQE',
#   'B0094X227I',
#   'B009B1D7JK',
#   'B00CQ35C1Q',
#   'B00SMCJB4Y'],
#  np.int64(2018): ['B0053BCO00',
#   'B004HHIB8U',
#   'B002BS47L2',
#   'B003O6E800',
#   'B006ZPAYB4']}

# %% [markdown]
# Nous avons appliqué notre système de recommandation au jeu B003ZSP0WW pour toutes les années du dataset. Le jeu n’apparaissant qu’à partir de 2013, les recommandations commencent à cette date.
# À partir de 2013, nous observons que les jeux recommandés évoluent chaque année, ce qui reflète les changements de structure dans le réseau jeu–jeu et dans les communautés détectées par Louvain.
# Ainsi, notre système de recommandation est sensible aux dynamiques temporelles du marché et montre comment les préférences des utilisateurs évoluent au fil des années.

# %%
game_id = "B003ZSP0WW"

community_evolution = []

for year in sorted(all_partitions.keys()):
    part = all_partitions[year]

    if game_id in part:
        comm = part[game_id]    # communauté du jeu
        size = sum(1 for g in part.values() if g == comm)   # taille de la communauté
        community_evolution.append((year, comm, size))

community_evolution
# Out:
# [(np.int64(2013), 7, 754),
#  (np.int64(2014), 4, 1545),
#  (np.int64(2015), 6, 1681),
#  (np.int64(2016), 0, 1967),
#  (np.int64(2017), 17, 334),
#  (np.int64(2018), 19, 70)]

# %%
import matplotlib.pyplot as plt

years_plot = [x[0] for x in community_evolution]
sizes_plot = [x[2] for x in community_evolution]

plt.figure(figsize=(10,5))
plt.plot(years_plot, sizes_plot, marker='o')

plt.title("Évolution de la taille de la communauté du jeu B003ZSP0WW")
plt.xlabel("Année")
plt.ylabel("Taille de la communauté")
plt.grid(True)

plt.show()

# %%
import pandas as pd

rows = []

for year, recs in all_recommendations.items():
    if isinstance(recs, list):
        rows.append({
            "année": int(year),
            "recommandations": ", ".join(recs)
        })

table_reco = pd.DataFrame(rows).sort_values("année")
table_reco
# Out:
#    année                                    recommandations
# 0   2013  B000IMYKQ0, B000FQ9R4E, B000IMWK2G, B0009VXBAQ...
# 1   2014  B002I0H79C, B000P46NMK, B0050SYX8W, B00BMFIXT2...
# 2   2015  B0050SYILE, B00BU3ZLJQ, B000FRU0NU, B002BSA20M...
# 3   2016  B00DB9JV5W, B00CMQTTZ2, B00YJJ0OQS, B00YQ1NOPM...
# 4   2017  B00JA81WQE, B0094X227I, B009B1D7JK, B00CQ35C1Q...
# 5   2018  B0053BCO00, B004HHIB8U, B002BS47L2, B003O6E800...

# %% [markdown]
# Les recommandations changent fortement d’une année à l’autre car la structure du réseau évolue.
# Les communautés se reforment chaque année en fonction des comportements des utilisateurs.
# Le jeu B003ZSP0WW passe d’un produit très central à un produit plus isolé, ce qui influence directement les recommandations.

# %%
import matplotlib.pyplot as plt

years = []
stability = []  # nb de recommandations communes entre deux années consécutives

sorted_years = sorted(all_recommendations.keys())

for i in range(1, len(sorted_years)):
    y_prev = sorted_years[i-1]
    y_curr = sorted_years[i]

    r_prev = all_recommendations[y_prev]
    r_curr = all_recommendations[y_curr]

    if isinstance(r_prev, list) and isinstance(r_curr, list):
        common = len(set(r_prev).intersection(r_curr))
        years.append(int(y_curr))
        stability.append(common)

plt.figure(figsize=(10,5))
plt.plot(years, stability, marker='o')
plt.title("Stabilité des recommandations d’une année à l’autre")
plt.xlabel("Année")
plt.ylabel("Nb de recommandations communes")
plt.grid(True)
plt.show()

# %% [markdown]
# La stabilité des recommandations diminue progressivement au fil du temps.
# Entre 2013 et 2014, deux jeux recommandés sont communs, puis un seul entre 2014 et 2015.
# À partir de 2016, la stabilité devient nulle : aucun des jeux recommandés une année n’est recommandé l’année suivante.
# Cette rupture s’explique par l’évolution de la structure du réseau : la communauté du jeu B003ZSP0WW se réduit drastiquement après 2016, ce qui modifie entièrement les clusters et donc les recommandations associées.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Récupérer le graphe 2015
G15 = all_graphs[2015]

print(" --- MÉTRIQUES SNA POUR 2015 ---")

print("Nombre de jeux (nœuds) :", G15.number_of_nodes())

print("Nombre de liens (arêtes) :", G15.number_of_edges())

avg_degree = sum(dict(G15.degree()).values()) / G15.number_of_nodes()
print("Degré moyen :", avg_degree)

components = list(nx.connected_components(G15))
print("Nombre de composantes connexes :", len(components))

largest_cc = max(components, key=len)
print("Taille de la plus grande composante :", len(largest_cc))

clustering = nx.average_clustering(G15)
print("Coefficient de clustering global :", clustering)

plt.figure(figsize=(8,5))
plt.hist([d for n, d in G15.degree()], bins=20, color='skyblue')
plt.title("Distribution du degré – Graphe 2015")
plt.xlabel("Degré")
plt.ylabel("Nombre de jeux")
plt.grid(True)
plt.show()
# Out:
#  --- MÉTRIQUES SNA POUR 2015 ---
# Nombre de jeux (nœuds) : 11968
# Nombre de liens (arêtes) : 280435
# Degré moyen : 46.86413770053476
# Nombre de composantes connexes : 14
# Taille de la plus grande composante : 11940
# Coefficient de clustering global : 0.5574756682482467

# %% [markdown]
# Le graphe jeu–jeu de 2015 présente une structure extrêmement dense et cohérente.
# Avec près de 12 000 jeux et plus de 280 000 arêtes, le degré moyen atteint 46.8, ce qui indique un niveau élevé de similarité entre les jeux notés par les mêmes utilisateurs.
# Le réseau est très connecté : la plus grande composante représente plus de 99.7% des nœuds, ce qui montre une forte cohésion globale.
# Le coefficient de clustering (0.557) est élevé, révélant des groupes bien structurés où les jeux fortement liés appartiennent souvent aux mêmes communautés de joueurs.

# %%
df['reviewerID'].sample(10).tolist()
# Out:
# ['A3BEQHZ88Z5QLI',
#  'AV1KYJXHOWPMD',
#  'A38CGA6QQF1BPI',
#  'A1WA2QPMTU16P5',
#  'A5USP82HL503I',
#  'A1QX1N4HS5GHID',
#  'AE7VVYWOHWBWW',
#  'A22YCFK2DRZTIV',
#  'ABO3O3SQNB0',
#  'A1ITVHRZE96PW5']

# %%
users = ['AJNDEJEVSLBS1','A2G5PZZRXGLKAV','A29EBTSLVW8DXA','A2PJ0IA52QDVPJ',
         'A50MT8XJFKBW0','A2582EOHKL7GP5','AGG0HXKRG5HGO','ACH2469V7GQA7',
         'A389C8VOQ4KT2T','A1OSRB5P27GPEW']

for u in users:
    count = df[df['reviewerID'] == u].shape[0]
    print(u, "→", count, "jeux notés")
# Out:
# AJNDEJEVSLBS1 → 8 jeux notés
# A2G5PZZRXGLKAV → 10 jeux notés
# A29EBTSLVW8DXA → 5 jeux notés
# A2PJ0IA52QDVPJ → 6 jeux notés
# A50MT8XJFKBW0 → 5 jeux notés
# A2582EOHKL7GP5 → 11 jeux notés
# AGG0HXKRG5HGO → 7 jeux notés
# ACH2469V7GQA7 → 11 jeux notés
# A389C8VOQ4KT2T → 6 jeux notés
# A1OSRB5P27GPEW → 13 jeux notés

# %%
user_id = "A1OSRB5P27GPEW"

user_games = df[df['reviewerID'] == user_id][['asin','overall','year']]
user_games
# Out:
#               asin  overall  year
# 253678  B00BGAA0SU      5.0  2014
# 256288  B00BI83EVU      2.0  2014
# 271407  B00D4WTO1M      2.0  2013
# 297588  B00GMFKYK8      4.0  2014
# 310395  B00J48MUS4      1.0  2014
# 316599  B00K31C478      4.0  2014
# 336719  B00MV7KVP4      4.0  2015
# 358468  B00WNGH0HK      4.0  2015
# 363767  B00YQ2KCWO      2.0  2016
# 366350  B00Z7V9P8K      5.0  2016
# 372325  B00ZQC73O8      3.0  2017
# 398456  B01EZAA2ZI      1.0  2016
# 404882  B01GW8YDLK      5.0  2018

# %%
user_id = "A1OSRB5P27GPEW"
user_games = df[df["reviewerID"] == user_id][["asin", "year"]]

results = []

for _, row in user_games.iterrows():
    asin = row["asin"]
    year = row["year"]

    partition = all_partitions.get(year, {})

    if asin in partition:
        comm = partition[asin]
        results.append((year, asin, comm))
    else:
        results.append((year, asin, None))

results
# Out:
# [(2014, 'B00BGAA0SU', 16),
#  (2014, 'B00BI83EVU', 16),
#  (2013, 'B00D4WTO1M', 4),
#  (2014, 'B00GMFKYK8', 16),
#  (2014, 'B00J48MUS4', 16),
#  (2014, 'B00K31C478', 16),
#  (2015, 'B00MV7KVP4', 3),
#  (2015, 'B00WNGH0HK', 3),
#  (2016, 'B00YQ2KCWO', 1),
#  (2016, 'B00Z7V9P8K', 1),
#  (2017, 'B00ZQC73O8', 3),
#  (2016, 'B01EZAA2ZI', 1),
#  (2018, 'B01GW8YDLK', 5)]

# %%
from collections import Counter

communities = [c for (_,_,c) in results if c is not None]

dominant_comm = Counter(communities).most_common(1)
dominant_comm
# Out:
# [(16, 5)]

# %% [markdown]
# L’utilisateur appartient principalement à la communauté 1, car :
#
# Il a joué 5 jeux de cette communauté
#
# C’est la communauté la plus fréquente dans son historique

# %%
user_id = "A1OSRB5P27GPEW"

# Jeux de l'utilisateur
user_games_list = df[df["reviewerID"] == user_id]["asin"].tolist()

# Année où la communauté dominante apparaît le plus
dominant_year = 2014
dominant_community = 1

partition = all_partitions[dominant_year]
G_year = all_graphs[dominant_year]

# Jeux appartenant à la communauté dominante
community_games = [g for g, c in partition.items() if c == dominant_community]

# On enlève les jeux déjà joués par l'utilisateur
candidate_games = [g for g in community_games if g not in user_games_list]

# On trie par degré (popularité interne de la communauté)
sorted_candidates = sorted(candidate_games, key=lambda g: G_year.degree(g), reverse=True)

# Top 10 recommandations
top_recommendations = sorted_candidates[:10]
top_recommendations
# Out:
# ['B00KFBX9XY', 'B00OBA6QYY']

# %% [markdown]
# L’utilisateur A1OSRB5P27GPEW a noté majoritairement des jeux appartenant à la communauté 1 en 2014.
# Cette communauté regroupe des titres fortement connectés dans le réseau, c’est-à-dire souvent co-notés par les mêmes groupes d’utilisateurs.
# Pour générer la recommandation, nous avons extrait les jeux non encore consommés par l’utilisateur et classés par degré dans le graphe jeu–jeu.
# Les jeux sélectionnés sont donc ceux qui occupent un rôle central dans la communauté, ce qui garantit une forte similarité avec ses préférences historiques.

# %%
all_graphs = {}

print("🔧 Construction des graphes jeu–jeu...")

for year in sorted(df["year"].unique()):
    df_y = df[df["year"] == year]

    G = nx.Graph()

    # Pour chaque utilisateur → ajouter des liens entre les jeux qu'il a notés
    for user, games in df_y.groupby("reviewerID")["asin"]:
        games = list(games)
        for i in range(len(games)):
            for j in range(i + 1, len(games)):
                G.add_edge(games[i], games[j])

    all_graphs[year] = G
    print(f"✔️ Graphe {year} : {len(G.nodes())} jeux, {len(G.edges())} liens")

# Sauvegarde dans un fichier pickle
with open("all_graphs.pkl", "wb") as f:
    pickle.dump(all_graphs, f)

print("\n🎉 Fichier all_graphs.pkl créé avec succès !")
# Out:
# 🔧 Construction des graphes jeu–jeu...
# ✔️ Graphe 1999 : 43 jeux, 113 liens
# ✔️ Graphe 2000 : 596 jeux, 5917 liens
# ✔️ Graphe 2001 : 1175 jeux, 20133 liens
# ✔️ Graphe 2002 : 1485 jeux, 32979 liens
# ✔️ Graphe 2003 : 1700 jeux, 41343 liens
# ✔️ Graphe 2004 : 1797 jeux, 29056 liens
# ✔️ Graphe 2005 : 2079 jeux, 37817 liens
# ✔️ Graphe 2006 : 2088 jeux, 40582 liens
# ✔️ Graphe 2007 : 2630 jeux, 42847 liens
# ✔️ Graphe 2008 : 3164 jeux, 49656 liens
# ✔️ Graphe 2009 : 3843 jeux, 61711 liens
# ✔️ Graphe 2010 : 3877 jeux, 38910 liens
# ✔️ Graphe 2011 : 4520 jeux, 53689 liens
# ✔️ Graphe 2012 : 5809 jeux, 124698 liens
# ✔️ Graphe 2013 : 8428 jeux, 114955 liens
# ✔️ Graphe 2014 : 10649 jeux, 213239 liens
# ✔️ Graphe 2015 : 11968 jeux, 280435 liens
# ✔️ Graphe 2016 : 11110 jeux, 229648 liens
# ✔️ Graphe 2017 : 8461 jeux, 97227 liens
# ✔️ Graphe 2018 : 4256 jeux, 26468 liens
#
# 🎉 Fichier all_graphs.pkl créé avec succès !

# %%
with open("all_graphs.pkl", "rb") as f:
    all_graphs = pickle.load(f)

all_partitions = {}

print("🔧 Détection des communautés Louvain...")

for year, G in all_graphs.items():
    if len(G.nodes()) == 0:
        all_partitions[year] = {}
        print(f"⚠️ Année {year} vide, ignorée.")
        continue

    partition = community_louvain.best_partition(G)
    all_partitions[year] = partition

    print(f"✔️ Louvain {year} : {len(set(partition.values()))} communautés")

with open("all_partitions.pkl", "wb") as f:
    pickle.dump(all_partitions, f)

print("\n🎉 Fichier all_partitions.pkl créé avec succès !")
# Out:
# 🔧 Détection des communautés Louvain...
# ✔️ Louvain 1999 : 7 communautés
# ✔️ Louvain 2000 : 16 communautés
# ✔️ Louvain 2001 : 10 communautés
# ✔️ Louvain 2002 : 12 communautés
# ✔️ Louvain 2003 : 15 communautés
# ✔️ Louvain 2004 : 25 communautés
# ✔️ Louvain 2005 : 34 communautés
# ✔️ Louvain 2006 : 35 communautés
# ✔️ Louvain 2007 : 65 communautés
# ✔️ Louvain 2008 : 48 communautés
# ✔️ Louvain 2009 : 62 communautés
# ✔️ Louvain 2010 : 89 communautés
# ✔️ Louvain 2011 : 112 communautés
# ✔️ Louvain 2012 : 77 communautés
# ✔️ Louvain 2013 : 48 communautés
# ✔️ Louvain 2014 : 35 communautés
# ✔️ Louvain 2015 : 27 communautés
# ✔️ Louvain 2016 : 46 communautés
# ✔️ Louvain 2017 : 76 communautés
# ✔️ Louvain 2018 : 141 communautés
#
# 🎉 Fichier all_partitions.pkl créé avec succès !
